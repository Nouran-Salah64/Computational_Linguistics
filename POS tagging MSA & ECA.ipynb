# %%
# pos tagging MSA
import regex as re
import nltk
from pyarabic import araby

file_ARB = open(r'C:\Users\test\Desktop\TASK 2 COMP\2000 MSA.txt','r', encoding='utf-8')
txt_ARB = file_ARB.read()
file_ARB.close()
txt_ARB = re.sub("\n", " ", txt_ARB)

plu_adj_n = [r'^المنازل$',r'^البنوك$', r'^القوانين$', r'^اليهود$', r'^الأزهار$', r'^أغصانها$', r'^الأهداف$', r'^الطلاب$', r'^نتائج$', r'^تفاعلات$', r'^سكانها$', r'^الزوار$', r'^الأغاني$', r'^الشوارع$', r'^الأعمال$', r'^الأساليب$', r'^الكبرى$', r'^الأسواق$', r'^نشطاء$', r'^نشاطات$', r'^جهود$']

sing_adj_n = [r'^أصلع$', r'^نصفين$', r'^الرياضات$', r'^سيجارته$', r'^أكثر$', r'^أحضان$', r'^مشاكل$', r'^أهمية$', r'^بألوانها$', r'^أركان$', r'^قصص$', r'^سيمفونية$', r'^الجبال$', r'^بالثلوج$', r'^تاركة$', r'^لوحات$', r'^أوراق$', r'^وجمالها$', r'^الأولاد$', r'^نورها$', r'^تلة$', r'^تجربة$', r'^البلاد$', r'^لأجل$', r'^الزهور$', r'^تعبير$', r'^الكلاب$', r'^القطط$', r'^توزيع$', r'^التكنولوجيا$', r'^بطولة$', r'^لتشجيع$', r'^توعية$', r'^تعليمية$']

perfective_verb_exceptions = [
    r'^فتح$', r'^أوقف$', r'^جئت$', r'^أرغب$', r'^تفهم$', r'^اندفع$', r'^انقسم$', r'^رفع$', 
    r'^اصطحب$', r'^وجدوا$', r'^كان$', r'^تمرد$', r'^أمرت$', r'^ليس$', r'^قرر$', 
    r'^وصلت$', r'^غادر$', r'^انقطعت$', r'^واضطررنا$', r'^تربت$', r'^كانت$', r'^قررت$', 
    r'^تذكرت$', r'^نسيت$', r'^قال$', r'^اكتشفت$', r'^عثر$', r'^وبدأت$', r'^ذهب$', 
    r'^كانت$', r'^قرر$', r'^أحب$', r'^اختار$', r'^وعاد$', r'^جلس$', r'^وتناولوا$', r'^عادوا$', 
    r'^نظروا$', r'^ورأوا$', r'^حمل$', r'^وصل$', r'^استمتع$', r'^شعر$', r'^جعل$', 
    r'^بدأ$', r'^أدرك$', r'^تقاسمها$', r'^أعجبت$', r'^ذهبت$', r'^قرأته$',  r'^بجد$',
    r'^قمنا$', r'^حققه$', r'^أجراها$', r'^أظهرت$', r'^قررت$', r'^انطلقت$', 
    r'^درست$', r'^تعهد$', r'^أكد$', r'^تم$', r'^حضر$', r'^أظهرت$', r'^أعلنت$', 
    r'^أطلق$', r'^بدأ$', r'^تكونوا$', r'^استمتعتم$', r'^تابعونا$', r'^دمتم$', 
    r'^سمع$', r'^حزم$', r'^وانطلق$', r'^وصل$', r'^أذهله$', r'^قابل$', r'^واتجه$', r'^وجد$', 
    r'^اكتشف$', r'^وفتحت$', r'^أدرك$', r'^اكتسبها$', r'^أصبحت$', r'^قرروا$', r'^عاشا$', 
    r'^كانا$', r'^وكان$', r'^قررا$', r'^بدأ$', r'^شعر$', r'^ظهر$', r'^كانت$', r'^فزع$', 
    r'^وركض$', r'^وبدأ$', r'^فاستلقى$', r'^اقترب$', r'^أصبح$', r'^استمر$', r'^توقف$', r'^واختفى$',
    r'^نزل$', r'^وقال$', r'^قال$', r'^اقترب$', r'^أجاب$', r'^ابتسم$', r'^فأجاب$', r'^فهمت$', 
    r'^يمكن$', r'^وركض$', r'^تذكر$', r'^وقرر$', r'^اختار$', r'^وحملها$',  r'^رأيتها$'
]

patterns = [
    (r'^(عمر|فارس)$', 'proper noun'),
    (r'[!؟.،":؛]', 'punctuation'),
    (r'^ألا$', 'conjunction + negation particle'),
    (r'^لا$', 'Negation particle'),
    (r'^مما$', 'preposition + relative pronoun'),
    (r'^(و|ل|ف)?(ربما|لم|يا|قد|هل)$', 'particle'),
    (r'^(ربما|لم|يا|قد|هل)$', 'preopsition + particle'),
    (r'^و?(الذين|اللواتي|اللاتي|التي|الذي|ما)$', "relative pronoun"),
    (r'^(و|ف)?(ذلك|هذا|هو|تلك|ذاك|هي|ذات|ماذا|ما)$', 'pronoun'),
    (r'^(ب|ل)(لذا|كأن|أو|بل|عندما|طالما|أما|منذ|لكن|إذا|بينما|أن|حيث|أي|ثم)(ه|هم|ها|ني)$', 'preposition + conjunction + personal pronoun'),
    (r'^(و)(لذا|كأن|أو|بل|عندما|طالما|أما|منذ|لكن|إذا|بينما|أن|حيث|أي|ثم)(ه|هم|ها|ني)$', 'conjunction + personal pronoun'),
    (r'^(ب|ل|و)?(لذا|كأن|أو|بل|عندما|طالما|أما|منذ|لكن|إذا|بينما|أن|حيث|أي|ثم)(ه|هم|ها|ني)$', 'conjunction + personal pronoun'),
    (r'^(ب|و|ل)(أو|بل|عندما|لذا|طالما|أما|منذ|لكن|كأن|إذا|بينما|أن|حيث|أي|ثم|ربما)$', 'preposition + conjunction'),
    (r'^(أو|بل|عندما|لذا|طالما|أما|منذ|لكن|كأن|إذا|بينما|أن|حيث|أي|ثم|ربما)$', 'conjunction'),
    (r'^و?(خلف|حول|تحت|عن|فوق|ل|ب|خلال|في|من|إلى|على|علي|إلي|لدي|غير|سوى|حتى|بعد|أمام|مع|مثل|نحو)(نا|كم|ك|هما|هم|ها|ه)$', "preposition + personal pronoun"),
    (r'^و(خلف|حول|تحت|عن|فوق|بين|ل|ب|خلال|في|من|إلى|على|علي|إلي|لدي|غير|سوى|حتى|بعد|أمام|مع|مثل|نحو)$', "conjunction + preposition"),
    (r'^(حول|تحت|عن|فوق|بين|ل|ب|خلال|في|من|إلى|على|علي|إلي|لدي|غير|سوى|حتى|بعد|أمام|مع|مثل|نحو|خلف)$', "preposition"),
    (r'(فقط|معًا|هناك)', 'adverb'),
    (r'^(أ|ن).+ة$', 'noun / adjective, feminine, singular, indefinite'),
    *[(pattern, 'noun / adjective plural') for pattern in plu_adj_n], 
    *[(pattern, 'noun / adjective singular') for pattern in sing_adj_n], 
    
    # Verb patterns (perfective and imperfective)
    *[(pattern, 'perfective verb') for pattern in perfective_verb_exceptions],
    (r'^(يكن|يمكن)$', 'imperfective verb, masculine, singular'),
    (r'^س[أنيت].+$', 'particle + imperfective verb, masculine, singular'),
    (r'^(ل|ب)[أنيت].+ان$', 'preposition + imperfective verb, masculine, dual'),
    (r'^(و)[أنيت].+ان$', 'conjunction + imperfective verb, masculine, dual'),
    (r'^(ل|ب)[أنيت].+$', 'preposition + imperfective verb, masculine, singular'),
    (r'^(و)[أنيت].+$', 'conjunction + imperfective verb, masculine, singular'),
    (r'^و[أنيت].+ن$', 'conjunction + imperfective verb, feminine, plural'),
    (r'^[أنيت].+وا$', 'imperfective verb, masculine, plural'),
    (r'^[أنيت].+ون$', 'imperfective verb, masculine, plural'),
    (r'^[أنيت].+(ان|ا)$', 'imperfective verb, masculine, dual'),
    (r'^[أنيت].+ن$', 'imperfective verb, feminine, plural'),
    (r'^[أنيت].+(ها|ه|نا|ك|ني)$', 'imperfective verb, masculine, singular + personal pronoun'),
    (r'^[أنيت].+$', 'imperfective verb, masculine, singular'),
    
    # Noun and Adjective patterns
    (r'كل', 'noun, singular'),
    (r'^لأجل$', 'preposition + adjective, masculine, singular, indefinite'),
    (r'^.{2}و.{1}هم$', 'noun, plural, indefinite + personal pronoun'), #! عيونهم
    (r'^ال.+ان$', 'noun, dual, definite'),
    (r'^ال.+ة$', 'noun / adjective, singular, definite, feminine'),
    (r'^ال.+ات$', 'noun, plural, definite, feminine'),
    (r'^ال.+ان$', 'noun, dual, definite, musuline'),
    (r'^ال.+ون$', 'noun, plural, definite, musuline'),
    (r'^ال.+ين$', 'noun, plural, definite, musuline'),
    (r'^وال.+ين', 'conjunction + noun, plural, definite, masculine'),
    (r'^وال.+', 'conjunction + noun, singular, definite, masculine'),
    (r'^ال.+', 'noun / adjective, singular, definite, masculine'),
    (r'^لل.+ات$', 'preposition + noun, plural, definite, feminine'),
    (r'^لل.+ين$', 'preposition + noun, plural, definite, musculine'),
    (r'^لل.+$', 'preposition + noun, singular, definite, musculine'),
    (r'^بال.+ة$','preposition + noun, singular, definite, feminine'),
    (r'^بال.+ات$','preposition + noun, plural, definite, feminine'),
    (r'^بال.+$','preposition + noun, singular, definite, masculine'),
    (r'^ب.+$','preposition + noun / adjective, singular, indefinite, masculine'),
    (r'^و.+ة$','conjunction + noun / adjective, singular, indefinite, feminine'),
    (r'^ل.+ة$','preposition + noun / adjective, singular, indefinite, feminine'),
    (r'^.+ات$', 'noun, plural, indefinite, feminine'),
    (r'^و.+(ك|هم|ه)$','conjunction + noun, singular, indefinite + personal pronoun'),
    (r'^.+(ك|هم|ه|ها)$','noun, singular, indefinite + personal pronoun'),
    (r'^.+ة$','noun / adjective, singular, indefinite, feminine'),
    (r'^ل.+$','preposition + noun / adjective, singular, indefinite, musuline'),
    (r'^.+ين$','noun / adjective, plural, indefinite, musculine'),
    (r'^و.+$','conjunction + noun / adjective, singular, indefinite, masculine'),
    (r'^.+ي$','noun / adjective, singular, indefinite, masculine + prersonal pronoun'),
    (r'^.+$','noun / adjective, singular, indefinite, masculine'),
]
reg_xp=nltk.RegexpTagger(patterns)
tagged=reg_xp.tag(araby.tokenize(txt_ARB))
for pair in tagged:
    print(pair)
# Out:
# ('هل', 'particle')
# ('يرغب', 'imperfective verb, masculine, singular')
# ('الولد', 'noun / adjective, singular, definite, masculine')
# ('في', 'preposition')
# ('فتح', 'perfective verb')
# ('حساب', 'noun / adjective, singular, indefinite, masculine')
# ('؟', 'punctuation')
# ('أوقف', 'perfective verb')
# ('فارس', 'proper noun')
# ('السيارة', 'noun / adjective, singular, definite, feminine')
# ('أمام', 'preposition')
# ('البنك', 'noun / adjective, singular, definite, masculine')
# ('.', 'punctuation')
# ('لقد', 'particle')
# ('جئت', 'perfective verb')
# ('للسحب', 'preposition + noun, singular, definite, musculine')
# ('،', 'punctuation')
# ('لا', 'Negation particle')
# ('أرغب', 'perfective verb')
# ('المزيد', 'noun / adjective, singular, definite, masculine')
# ('.', 'punctuation')
# ('لم', 'particle')
# ('تفهم', 'perfective verb')
# ('بعد', 'preposition')
# ('،', 'punctuation')
# ('يا', 'particle')
# ('رجل', 'noun / adjective, singular, indefinite, masculine')
# ...

# %%
# farasa (MSA)
import json
import requests
url = 'https://farasa.qcri.org/webapi/pos/'
text = txt_ARB
api_key = "jIGVxLtHkXJiJkdIYY"
payload = {'text': text, 'api_key': api_key}
data = requests.post(url, data=payload)
result = json.loads(data.text)
print(result)
# Out:
# {'text': [{'surface': 'S', 'POS': 'S', 'num': '', 'position': 'B'}, {'surface': 'هل', 'POS': 'PART', 'num': '', 'position': 'B'}, {'surface': 'يرغب', 'POS': 'V', 'num': '', 'position': 'B'}, {'surface': 'ال+ ولد', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'في', 'POS': 'PREP', 'num': '', 'position': 'B'}, {'surface': 'فتح', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'حساب', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '؟', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': 'أوقف', 'POS': 'V', 'num': '', 'position': 'B'}, {'surface': 'فارس', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'ال+ سيار +ة', 'POS': 'DET+NOUN+NSUFF', 'num': 'FS', 'position': 'B'}, {'surface': 'أمام', 'POS': 'NOUN', 'num': 'MS', 'position': 'B'}, {'surface': 'ال+ بنك', 'POS': 'DET+NOUN', 'num': 'MS', 'position': 'B'}, {'surface': '.', 'POS': 'PUNC', 'num': '', 'position': 'B'}, {'surface': 'لقد', 'POS': 'PART', 'num': '', 'position': 'B'}, {'surfa
# ...

# %%
# pos tagging ECA
import nltk
import re
file=open(r'C:\Users\test\Desktop\TASK 2 COMP\2000 ECA.txt','r',encoding='UTF-8')
myfile=file.read()
# Define morphological patterns for ECA (Egyptian Colloquial Arabic)
morphological_patterns = [
    # Nouns (Definite plural masculine, feminine, general)
    (r'^ال.+ون$', 'Noun def plural masc'),
    (r'^ال.+ين$', 'Noun def plural masc'),
    (r'^ال.+ات$', 'Noun def plural fem'),               
    # Pronouns
    (r'^و?(من|على|مع|إلى|من|عن|ب|ك|ل|و|في|على|عشان|بـ|ما|مش|لـ|لك|فيه|اللي|أومال|ف)$', 'Preposition/Particle'),
    (r"^م.+تش$","verb perfect singular 1st person negated"),
    (r'^وما.+?تش$','verb perfect singular 1st person negated'),         
    (r'^(تمام|تماما)$','noun singular indefinite'), 
    (r'^(فين|اي|ايه|اى|اية|هل)$','verb interrogative'),
    (r'^(اللواتي|اللاتي|التي|الذي|ما|اللي|كل|إللي|كله|اللى|معاهم|كلهم|إلي|أي|إي|أى)$',"relative"),
    (r'^(إلى|في|من|عن|علي|على|فى|الي|الى|ب|ك|ل|عشان|لك|أو|او|وفي|وكل|يا|بس|و|فيه|منه|كدا|وعشان|وبقى|والا|كدة|ثم|وثم|إلا|وانه|كذلك|الأخرى|ولهذا|غيره|كي|أنها|تلك|ولكننى|انك|شئ|برضو|ألستم)$',"preposition\\particles"),
    (r'^(فوق|تحت|بعض|بعد|جنب|لما|زي|جدا|حاجه|حاجة|اوي|اوى|دي|دى|ده|اغلب|هنا|كمان|اي|مهما|قريب|قد|مره|مرة|بجد|دلوقتي|دلوقت|فقط|لها|ذلك|طول|بيها|بيهم|منها|فيها|ليها|ومن|شوية|خلي|خالص|أما|ليه|عليه|أنك|حتي|حتى)$','particles'),
    (r"^(مفيش|مش|ومش|ومفيش)$","neglected,relative,prep,noun"),
    (r'^(أنا|انا|إنتي|أنت|انت|انتي|انتى|هو|هي|هما|هن|هم|إحنا|احنا|اني|انى|وأنا|أنتى)$','pronoun'),
    (r'كنت|كان|كنتم|لما', 'Verb past '),
    (r'هلكني',"Verb Present + Possisive"),                
    # Verbs: Special Cases
    (r'^(بقى|لقى|بعت|ضحك|لقي)$', 'Verb Past 3rd Masc'),  # Past tense, meaning "became"
    # Verbs (Present tense masculine and feminine)
    (r'^ي.+', 'Verb present 3rd masc singular'), 
    (r'^ي.+ون$', 'Verb present 3rd masc plural'),
    (r'^ت.+', 'Verb present 3rd fem singular'),
    (r'^بال.+$',"preposition + Noun Definite"),
    # Verbs: Present Tense

    (r'^م.+?ش$', 'verb negatiation 3rd'),
    (r'^ما.+?ش$','verb negected past'),
    (r'^ي.+?وا$','verb present 3rd masc plural'),
    (r'^ال.+?ات$', 'det + Noun def plural fem'),
    (r'^ال.+?ة$', 'det + Noun def singular fem'),
    (r'^ال.+$', 'det + Noun def'),
    (r'^بال.+', 'prep + det + noun def'),
    (r'^.+?ين$', 'verb imperfect 3rd musc Plural'),
    (r'^و.+تو$', 'Verb past 2nd masc plural (with conjunction)'),
    (r'^ما.+ش$', 'Verb negated past'),    
    (r'^ي.+وا$', 'Verb Present 3rd Masc Plural'),    
    (r'^بن.+$', 'Verb Present Continuous'),
    (r'^بت.+$', 'Verb Present Progressive'),
    (r'^ي.+$', 'Verb Present 3rd Masc Sing'),
    (r'^ت.+$', 'Verb Present 3rd Fem'),
    (r'^ب.+', 'Verb present continuous'),       
    (r'^ه.+', 'Verb future'),                   
    (r'.+وا$', 'Verb Past 3rd Plural'),
    (r'^م.{2}ش$', 'preposition (negative)'),                         
    (r"^أجمل$","صفة"),
    (r"^ولا$","prep+ negative"),
    (r"^بت.+?$","future verb"),   
    (r'(،|\.|\؟|!)', 'punctuation'),
    (r"^ال.+?ون$","noun,det,musc,plural"),
    (r'^ال.+?ين$','noun def plural masc'),
    (r"^وال.+?ات$","conj+det+noun,fem,plural"),
    (r'^(ح|ه).+ها$',"verb present+ Possisive"),
    (r"^ي.+?ون$","present,verb,third person,plural"),                
    (r"مما","prep+relative"),
    (r"^ت.+?ن$","verb ,third person,fem,plural"),
    (r"^ت.+?هن$","verb,third per,plural,fem"),
    (r"^ال.+?ة$","feminin noun"),
    (r"^وي.+?ون$","conj,present,verb,third person,plural"),
    (r"^ي.+?ن$","present,verb,third person,plural,fem"),
    (r"^و.+?ن$","present,verb,third person,plural,fem"),
    (r"^.+?ين$","third person,plural,past"),
    (r"^و(ي|ت|ن)", "present verb"),
    (r'^لل.+ات$', 'prep + Noun plural fem'),
    (r'.+ات$', 'noun plural fem'),
    (r"^.+?ت$","past verb"),
    (r'^ب.+هن$', 'prep + noun plural fem'),
    (r'^.+هن$', 'noun plural 3rd fem'),
    (r'^(لل|ب).+', 'prep + noun'),
    (r'^لت.+', 'prep + verb'),   
    (r"^ل.+","اسم مجرور+حرف جر"),
    # General patterns    
    (r'.+?وا$','verb past 3rd plural'),
    (r'.+?ها$','noun 3rd fem possessive'),
    (r'.+?ه$','noun 3rd masc possessive'),
    (r'^ال.+ة$', 'Noun Def Singular Fem'),
    (r'^ال.+$', 'Noun Def'),    
    (r".+?ة$","noun undef singular fem"),
    (r"^.+?نا$","noun duel"),
    (r'.+?تين$','noun duel fem'),               
    (r'.+ها$', 'Noun 3rd Fem Possessive'),  
    (r'.+ه$', 'Noun 3rd Masc Possessive'),  
    (r'.{2}$', 'Short word'),
    (r'.*', 'Noun indef or Adjective'),
]


# Create the RegexpTagger
regexp_tagger = nltk.RegexpTagger(morphological_patterns)

# Input text
eca_text = myfile
eca_text=re.sub(r"[\?؟,\.\":،\\]","",eca_text)
# Tokenize the text into words
tokens = eca_text.split()

# Apply the tagger to the tokens
tagged_data = regexp_tagger.tag(tokens)

# Display the tagged tokens
for word, tag in tagged_data:
    print(f"{word}: {tag}")
# Out:
# حكايتنا: noun duel
# اليوم: det + Noun def
# عن: Preposition/Particle
# سلحفاة: noun undef singular fem
# كانت: Verb past
# بتعيش: Verb Present Progressive
# في: Preposition/Particle
# غابة: noun undef singular fem
# مليانة: noun undef singular fem
# أكل: Noun indef or Adjective
# يكفي: Verb present 3rd masc singular
# كل: relative
# الحيوانات: Noun def plural fem
# كان: Verb past
# المميز: det + Noun def
# في: Preposition/Particle
# الغابة: det + Noun def singular fem
# دي: particles
# ان: Short word
# كان: Verb past
# فيه: Preposition/Particle
# نهر: Noun indef or Adjective
# كبير: Noun indef or Adjective
# اوي: particles
# النهر: det + Noun def
# ده: particles
# كانت: Verb past
# بتشرب: Verb Present Progressive
# منه: preposition\particles
# بقيت: Verb present continuous
# الحيوانات: Noun def plural fem
# السلحفاة: det + Noun def singular fem
# كانت: Verb past
# طيبة: noun undef singular fem
# جدا: particles
# وعشان: Preposition/Particle
# كدا: preposition\particles
# ...
