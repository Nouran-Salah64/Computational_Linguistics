# %%
# morphological analysis MSA
import regex as re
file_ARB = open(r'C:\Users\test\Desktop\TASK 2 COMP\2000 MSA.txt','r', encoding='utf-8')
txt_ARB = file_ARB.read()
file_ARB.close()
txt_ARB = re.sub("\n", " ", txt_ARB)

#! lists of stems
v_stem = ['رغب','فتح','حكي','فزع','قف','حل','دم','تابع','جئت','رغب','فهم','اندفع','انقسم','رفع','اصطحب','زائر','وجد','مرد','جعل','فتقد','اقتحام','بدو','دل','نفث','فكر','فتح','أمر','معرض','صعد','قرر','زور','لعب','جلس','تحدث','وصل','غادر','انقطع','اضطرر','تشابك','ترب','تخلل','قرر','استرخاء','ذكر','نسي','تعلم','عيش','حيط','قال','حذر','جلب','ستخدم','حب','استكشاف','أماكن','اكتشف','تحدث','عيش','عثر','وصل','بدأ','تحدث','كون','كن','ذهب','تراقص','مرح','جري','أحب','تمايل','اكتشاف','اختار','عاد','تناول','شعر','استمتاع','ستمتع','نظر','رأ','شرق','عكس','تلألأ','قضي','استكشاف','حمل','خرج','وصل','تفتح','شرح','استمتع','تلاشى','تم','تقاسم','تفتح','قتصر','غني','رفع','ضيف','تدفق','خلق','شعر','مكن','ريح','أفق','تارك','عكس','دعو','سمع','غرب','شارك','أعجب','شرح','روي','لعب','حمل','مرح','درس','جعل','ذهب','قرأ','فوح','حتوي','جعل','نشر','جذب','تميز','عيش','رغب','حقق','ستضيف','أجر','ظهر','قم','ظهر','قع','جمع','جذب','مكن','قام','ستعد','جعل','كان','عتقد','حتضن','تجول','شعر','درس','حصل','بدأ', 'اختار', 'حمل', 'وجد', 'رأي', 'واجه', 'ناسب', 'شعر', 'حير', 'وافق', 'ركض', 'كون', 'مكن', 'أصبح', 'قال', 'اقترب', 'جاب', 'تنفس', 'تحرك', 'ابتسم', 'تكلم', 'قول', 'فهم', 'كان', 'نزل', 'راقب', 'قرر', 'بتعد', 'فحص', 'شكل', 'اختفى', 'مر', 'ظل', 'استلقى', 'تجنب', 'شم', 'أوقف', 'ظهر', 'توهج', 'تسلق', 'شتهر', 'زداد', 'لتف', 'حيط', 'صطاد', 'فرق', 'ذهب', 'حيط', 'عاش', 'قضي', 'كشف', 'درك', 'تجارب', 'اكتسب', 'وصل', 'فتح', 'اكتشف', 'قابل', 'عرض', 'قرر', 'شير', 'اتجه', 'سمع', 'حزم', 'طلق', 'ذهل', 'حكي', 'تيح', 'عيش', 'عتبر', 'كون', 'استمتع', 'ساعد', 'نصح', 'أمل', 'ؤمن', 'سعى', 'تواجد', 'طلق', 'تهدف', 'تضمن', 'مكن', 'مهتم', 'أعلن', 'تم', 'ستعد', 'لعب', 'ثق', 'حضر', 'ظهر', 'أكد', 'قلل', 'ؤثر', 'طلع', 'تطلع', 'ضم', 'مثل', 'حيي', 'عهد', 'تقام', 'تفتح', 'ستخدم', 'قف', 'نضب','ستمتع','مطر','شرق','نضب','عثر','ليس','تدفق','أدرك']
n_stem = ['ولد','مليء','حساب','كل','تطوير','شديد','فارس','أولى','معًا','عضل','حملة','سيارة','بنك','سحب','مزيد','رجل','حجرة','جانبي','وحيد','بنك','بدين','أصلع','استخدام','رأس','حلة','أنيق','رتدي','فريق','مطاردة','نصف','رأي','لص','جميع','عيون','بنوك','مصدر','صوت','كوكب','مهمة','دكتور','عالم','قرن','خامس','عصر','بريق','عصب','خطوط','إتصال','مقطوع','منزل','فخم','ترتيب','باب','منزل','كسر','محاول','سرق','صاحب','عنق','منحور','ضابط','دخان','سيجارت','مكان','جريمة','شرود','فحص','كدم','جسد','قتيل','وضع','خارج','هادئ','أكثر','لازم','منازل','قريب','مجمع','سكن','مارة','شارع','شخص','حارس','عقار','غرف','حديقة','وقت','طويل','قمة','إحترافية حافلة ','تخطيط','قتيل','دقة','حصول','دليل','معرفة','عناية','خاص','طعام','خطر','حافلة','صور','مدرسة','سعادة','زواج','حل','أمثل','إستقرار','مجموع','قوانين','مدنية','عدد','متزايد','عمال','مأجور','ريف','قوت','عائلة','كافيا','شراء','حبوب','مكلف','محاصيل','سيئ','جد','نهاية','اسبوع','أطفال','حديقة','أم','محطة','قطار','كهرباء','فجأة','شموع','قلب','حارة','يهود','جنوب','تونسي','أحداث','مسلم','يتيم','أحضان','عائلة','سماء','مدينة','غارق','ظلال','أنوار','شوارع','ضباب','كثيف','يوم','طويل','عمل','مشاهدة','فيلم','إطفاء','إطفاء','مصباح','غرفت','مهارة','جديد','عطلة','نهاية','قرية','صغير','جبال','خضراء','محاط','عالي','هدوء','أشجار','مكان','ساحر','نائية','كنز','مشاكل','حكمة','بلد','صغير','محاط','غاب','سحر','فتاة','طبيعة','بحيرات','ولد','قرية','صغير','ضفاف','نهر','زرع','بسيط','جميل','لون','مبهج','جذاب','خريطة','قديم','مخبأ','ذهب','فضة','قمة','جبل','منظر','سماء','جميل','نجوم','كبير','مساء','بعض','داخل','حيث','مجرد','جيد','حديقة','قريب','أزهار','كرة','قراءة','مكتبة','عوالم','كتب','مجموعة','قصص','مثير','مساء','خلفي','عائلت','عشاء','ضوء','قمر','خطة','ذهاب','نزهة','جبال','قضاء','يوم','ممتع','طبيعة','عاد','تعب','قلوب','فرح','فرصة','تواصل','أصدقاء','أشياء','نيابة','والد','أهمية','وقت','ناس','سباحة','بناء','قلاع','بحر','شمس','غروب','قضاء','ألوان','دافئ','رملية','جمال','ماء','ضرورة','عودة','أصل','احترام','بيئة','معظم','غاب','حقول','حقيبت','نهاية','صباح','مشمس','ألوان','مدهش','زاهية','لطف','نسيم','عليل','صوت','أشعة','طيور','جمال','ساحرًا','الفعل','تنظيم','سعادة','عمر','سماء','طبيعي','لمس','هدوء','ركن','عتيق','مناظر','أركان','لحظ','آخر','تفتيش','شلال','هموم','صخور','أغصان','زمن','قصص','مياه','منظر','ماضي','مصدر','طاقة','خلف','سيمفونية','نفس','طبيعي','راحة','شاهق','لوح','مكسو','حراسة','فنية','سحري','عيش','عطر','لحظة','شجر','ثلوج','أوراق','سعادة','نسيم','زهرة','انتعاش','صوت','قصة','فريد','درس','بنت','حكاي','جميل','جو','حياة','يوم','أولاد','مدرسة','عام','فرحت','كبير','كتاب','وسط','مفيد','مدينة','زهور','مدرسة','ملون','طالب','جديد','كتاب','عصافير','ساطع','عطلة','طالب','عديد','قيم','صف','دراسي','متفوق','اختبار','نهائي','ذهبي','صافي','سماء','قديم','نور','جد','معلوم','تل','خضراء','رحلة','بحري','إطلالة','رائع','اجتهاد','صيف','تجربة','ماضي','وادي','خلاب','مناطق','جبلي','مليئ','كبير','ذكري','أسرة','كثير','مجاور','سياح','سكينة','عائلي','مناسب','نهاية','نجاح','فريق','بطولة','إصرار','عطلة','جماعي','مغامر','تحقيق','علمي','تجربة','علوم','مختبر','طلاب','أهداف','نتائج','احتفال','عمل','سنوي','مواد','مثير','مختلف','جميع','تفاعل','مدينة','سكان','موروث','احتفال','وطني','منتزه','أنحاء','زوار','طبيعي','بلاد','ثقافي','عديد','فنية','مناظر','قمة','رؤيت','هواء','شخص','رائع','بحر','نزهة','نقي','جد','صباح','شلال','درج','أكبر','حياة','مدينة','قرية','مكتبة','عالي','انتهاء','دروس','دهشة','قضاء','جديد','وقت','سماء','عائلت','قراءة','بقاء','عبر','فقط','إلهام','اختيار', 'صخور', 'كلام', 'رجل', 'مسن', 'واحد', 'وقت', 'طويل', 'صخر', 'طريق', 'صعوبة', 'عود', 'حياة', 'كثير', 'فرص', 'تحدي', 'أمور', 'مغري', 'شاب', 'فور', 'جبل', 'وصل', 'قمة', 'عرف', 'وقت', 'صعب', 'شيء', 'محل', 'أصدقاء', 'حقيقي', 'صمت', 'أخطر', 'كلام', 'حادث', 'أكثر', 'مضى', 'قيمة', 'حيات', 'صداقت', 'موقف', 'أعلى', 'صديق', 'دب', 'أرض', 'صديق', 'لحظة', 'نظر', 'آخر', 'شجرة', 'نهاية', 'خطو', 'تهديد', 'ثقيل', 'ظلام', 'لحظة', 'خوف', 'لحظ', 'ساع', 'وصول', 'أمل', 'انتباه', 'هواء', 'تظاهر', 'متر', 'موت', 'عين', 'قلب', 'ضخم', 'سرعة', 'أول', 'مسرعًا', 'كبيرة', 'رعب', 'بعيد', 'أعماق', 'غابة', 'مكان', 'قرية', 'كثافة', 'أشجار', 'كثرة', 'حيوان', 'بري', 'عمق', 'جو', 'ظلمة', 'غريب', 'مجاور', 'ضفاف', 'نهر', 'بسيط', 'سعيد', 'أسماك', 'صداقت', 'قوية', 'أحد', 'أيام', 'رحلة', 'ثمار', 'مليئ', 'إلهام', 'نائية', 'قريت', 'دور', 'بحث', 'مغامر', 'خاص', 'كنوز', 'واكتشاف', 'يوم', 'هناك', 'طفولت', 'بواب', 'معرفة', 'قوة', 'نطق', 'جملة', 'صوت', 'عال', 'بطء', 'غرفة', 'تحف', 'قديم', 'قيم', 'مجوهر', 'ذهب', 'مصدر', 'مسجد', 'قلعة', 'مدمر', 'مشي', 'مغلق', 'أقفال', 'نقوشًا', 'جدران', 'سر', 'قراءة', 'نصوص', 'سحري', 'فتح', 'جملة', 'رحلت', 'زيارة', 'سوق', 'بائع', 'عجوز', 'خرائط', 'أدوات', 'غامض', 'شراء', 'خريطة', 'مكان', 'كنز', 'خفي', 'اتباعًا', 'إرشاد', 'موجود', 'ساحة', 'رئيسي', 'مدينة', 'شمال', 'مرورًا', 'معالم', 'أجيال', 'سابق', 'حقيبت', 'صغير', 'مغامرت', 'عتيق', 'جمال', 'أزقة', 'ضيق', 'أسواق', 'مزدحم', 'حجارة', 'مرصوف', 'قصص', 'ماضي', 'مجتمع', 'سفر', 'جرب', 'ممتع', 'ثقاف', 'جديد', 'مهم', 'تخطيط', 'شكل', 'جيد', 'ضمان', 'مميز', 'إحدى', 'قرى', 'هادئ', 'يوم', 'نهر', 'أنواع', 'رواي', 'كتب', 'علمي', 'كرة', 'قدم', 'سباح', 'فضل', 'مختلف', 'رياض', 'ممارسة', 'رياضة', 'منتظم', 'جري', 'كتاب', 'سباحة', 'وسيلة', 'فعال', 'تحسين', 'لياقة', 'بدني', 'تقوية', 'مرآة', 'ثقافة', 'مقال', 'دمت', 'خير', 'لقاء', 'أعداد', 'قادم', 'حصول', 'مزيد', 'أخبار', 'عدد', 'مقبل', 'قراءة', 'فكر', 'زيادة', 'معرفة', 'أقل', 'شهر', 'عديد', 'تسجيل', 'إنترنت', 'إشراك', 'جهود', 'حفاظ', 'بيئة', 'مشروع', 'منزل', 'إرادة', 'عمل', 'قوة', 'جاد', 'تحقيق', 'أهداف', 'مساعدة', 'آخر', 'أحلام', 'قدرة', 'لاعب', 'فوز', 'جماهير', 'تشجيع', 'فريق', 'نشطاء', 'توعية', 'حماية', 'غاب', 'هدف', 'تنوع', 'بيولوجي', 'برنامج', 'نشاط', 'تعليمي', 'ميداني', 'صحة', 'نفسي', 'عكس', 'صحيح', 'شركة', 'تكنولوجي', 'كبرى', 'إطلاق', 'هاتف', 'جديد', 'طرح', 'أسواق', 'اسبوع', 'مقبل', 'بطولة', 'دوري', 'مبار', 'جمعة', 'مدرب', 'تنوع', 'أساليب', 'فني', 'افتتاح', 'عشاق', 'فن', 'مثقف', 'دراسة', 'أهمية', 'تحسين', 'باحث', 'نشاط', 'بدني', 'أعراض', 'اكتئاب', 'جسدي', 'إيجابي', 'ناس', 'سرعة', 'كفاءة', 'عالي', 'متابعة', 'صفحت', 'وسائل', 'تواصل', 'اجتماعي', 'لقائ', 'قادم', 'افتتاح', 'معرض', 'فني', 'جديد', 'مركز', 'ثقافي', 'يوم', 'سبت', 'أعمال', 'مجموع', 'فنان', 'محلي', 'دولي', 'كبير', 'عام', 'حفلة', 'فرقة', 'مشهور', 'متنوع', 'أغاني', 'دخول', 'مجاني', 'أفراد', 'أسرة', 'كشف', 'اختراع', 'مجال', 'جهاز', 'تسهيل', 'عملية', 'واسع', 'نظافة', 'بيئة', 'توزيع', 'قفاز', 'أكياس', 'مشاركة', 'عمدة', 'توفير', 'دعم', 'لازم', 'شوارع', 'نظيفة', 'مدرب', 'أهمية', 'عمل', 'جماعي', 'نجاح', 'موسيقي', 'زهور', 'فصل', 'ربيع', 'تعبير', 'غزارة', 'معلوم', 'دلالة', 'كلاب', 'ممتلك', 'قطط', 'منازل', 'أليف', 'مفيد', 'مغذي', 'طعام', 'جسم', 'أصدقاء', 'مخلص', 'جانب', 'صباح', 'اثنين', 'يوم', 'تنظيف', 'تحليل', 'اكتشاف', 'كاف','أليف','جميلاً','رحل','حماية','حفاظ']
prep_stem = ['في','من','إلى','على','علي','ب','ل','نحو','مثل','مع','أمام','بعد','حتى','سوى','غير','لدي','خلال','بين','فوق','عن','تحت','حول','منذ']
Pronouns_stem = ['هذا','هو','تلك','ذات','ماذا','ذلك','تلك','ذاك','اللاتي','ما','اللواتي','التي','هي','الذي','الذين']
particles = ['لا','قد','لم','يا','هل','أو','أي','حيث','ثم','لم','مما','أن','بينما','عندما','أجل','إذا','كأن','ربما','لكن','أما','أو','طالما','ذات','لذا','عندما','بل','هناك','ألا']

#! proclitics (nouns and verbs)
question = ['أ']
conjunction = ['ف','و']
particle_V = ['ل','س']

particle_N = ['ك','ب','ل']
def_article_N = ['ال','ل']

#! Prefixes (verbs only)
prefix = ['أ', 'ن', 'ي', 'ت']

#! Enclitics
enclitics = ['ك','كما','كن','كم','كمو','ه','ها','هما','هم','هن','ي','نا', 'ني']

#! Suffixes
past_suf = ['ت', 'ن', 'وا', 'و', 'ا', 'تما', 'نا', 'تن', 'تم']
present_Suf = ['ين', 'ي', 'ا', 'ان', 'ون', 'و', 'وا', 'ن' ]
gender_suf = ['ة','ت']
dual_suf = ['ان', 'ين', 'ا', 'ي']
plural_suf = ['ات', 'ون', 'ين', 'و', 'ي','هات']

#* to remove duplication if exist
v_stem = list(set(v_stem))
n_stem = list(set(n_stem))
prep_stem = list(set(prep_stem))
particles = list(set(particles))
Pronouns_stem = list(set(Pronouns_stem))

#* len of stems
print('no. of verb stems: ', len(v_stem))
print('no. of noun stems: ', len(n_stem))
print('no. of prepositions: ', len(prep_stem))
print('no. of particles: ', len(particles))
print('no. of pronouns: ', len(Pronouns_stem))

#* patterns for verbs
patterns_v = [
    ("^("+"|".join(conjunction)+")"+"("+"|".join(prefix)+")"+"(.+?)"+"("+"|".join(present_Suf)+")$", 3),
    ("^("+"|".join(conjunction)+")"+"("+"|".join(prefix)+")"+"(.+?)$", 3),
    ("^("+"|".join(conjunction)+")"+"(.+?)"+"("+"|".join(past_suf)+")$", 2),
    ("^("+"|".join(conjunction)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
    ("^("+"|".join(conjunction)+")"+"(.+)$", 2),
    
    ("^("+"|".join(prefix)+")"+"(.+?)"+"("+"|".join(present_Suf)+")$", 2),
    ("^("+"|".join(prefix)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
    ("^("+"|".join(prefix)+")"+"(.+?)"+"("+"|".join(dual_suf)+")$", 2),
    ("^("+"|".join(prefix)+")"+"(.+)$", 2),
    
    ("^("+"|".join(particle_V)+")"+"(.+)$", 2),
    ("^("+"|".join(particle_V)+")"+"("+"|".join(prefix)+")"+"(.+)$", 3),
    
    ("^(.+?)"+"("+"|".join(past_suf)+")"+"("+"|".join(enclitics)+")$", 1),
    ("^(.+?)"+"("+"|".join(gender_suf)+")"+"("+"|".join(dual_suf)+")$", 1),
    ("^(.+?)"+"("+"|".join(past_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(plural_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(enclitics)+")$", 1), 
    ("^(.+?)"+"("+"|".join(gender_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(dual_suf)+")$", 1), 
    ("^(.+)$", 1)
]

#* patterns for nouns
patterns_n = [  
    ("^("+"|".join(particle_N)+")"+"("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(plural_suf)+")$", 3),
    ("^("+"|".join(particle_N)+")"+"("+"|".join(def_article_N)+")"+"(.+?)$", 3),
    ("^("+"|".join(particle_N)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
    ("^("+"|".join(particle_N)+")"+"(.+?)"+"("+"|".join(plural_suf)+")$", 2),
    ("^("+"|".join(particle_N)+")"+"(.+)$", 2),

    ("^("+"|".join(conjunction)+")"+"("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(plural_suf)+")$", 3),
    ("^("+"|".join(conjunction)+")"+"("+"|".join(particle_N)+")"+"("+"|".join(def_article_N)+")"+"(.+?)$", 3),
    ("^("+"|".join(conjunction)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
    ("^("+"|".join(conjunction)+")"+"(.+?)"+"("+"|".join(gender_suf)+")$", 2),
    ("^("+"|".join(conjunction)+")"+"("+"|".join(def_article_N)+")"+"(.+?)$", 3),
    ("^("+"|".join(conjunction)+")"+"(.+)$", 2),

    ("^("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(gender_suf)+")$", 2),
    ("^("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(dual_suf)+")$", 2),
    ("^("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(plural_suf)+")$", 2),
    ("^("+"|".join(def_article_N)+")"+"(.+)$", 2),

    ("^(.+?)"+"("+"|".join(gender_suf)+")"+"("+"|".join(enclitics)+")$", 1),
    ("^(.+?)"+"("+"|".join(plural_suf)+")"+"("+"|".join(enclitics)+")$", 1),
    ("^(.+?)"+"("+"|".join(gender_suf)+")"+"("+"|".join(dual_suf)+")$", 1),
    ("^(.+?)"+"("+"|".join(gender_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(dual_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(plural_suf)+")$", 1), 
    ("^(.+?)"+"("+"|".join(enclitics)+")$", 1), 
    ("^(.+)$", 1)
]

#* patterns for prepositions
patterns_prep = [
    ("^("+"|".join(def_article_N)+")"+"(.+)$", 2),
    ("^("+"|".join(def_article_N)+")"+"(.+?)"+"("+"|".join(gender_suf)+")$", 2),
    
    ("^("+"|".join(particle_N)+")"+"("+"|".join(def_article_N)+")"+"(.+?)$", 3),
    
    ("^("+"|".join(conjunction)+")"+"(.+)$", 2),
    
    ("^(.+?)"+"("+"|".join(enclitics)+")$", 1), 
    ("^(.+?)"+"("+"|".join(plural_suf)+")$", 1), 
    ("^(.+)$", 1)
]

#* patterns for pronouns
patterns_pron = [
    ("^("+"|".join(conjunction)+")"+"(.+)$", 2),
    ("^(.+)$", 1)
]

#* patterns for particles
patterns_particles = [
    ("^("+"|".join(particle_N)+")"+"(.+)$", 2),
    ("^("+"|".join(conjunction)+")"+"(.+)$", 2),
    ("^(.+?)"+"("+"|".join(enclitics)+")$", 1),    
    ("^(.+)$", 1)
]
# Out:
# no. of verb stems:  193
# no. of noun stems:  656
# no. of prepositions:  23
# no. of particles:  25
# no. of pronouns:  14

# %%
# verbs MSA
for word in txt_ARB.split():
    for pat in patterns_v:
        match = re.search(pat[0], word)
        if match: 
            if match.group(pat[1]) in v_stem:
                    print(word, match.groups())
                    print('______________')
# Out:
# يرغب ('ي', 'رغب')
# ______________
# فتح ('فتح',)
# ______________
# أوقف ('أوقف',)
# ______________
# جئت ('جئت',)
# ______________
# أرغب ('أ', 'رغب')
# ______________
# تفهم ('ت', 'فهم')
# ______________
# اندفع ('اندفع',)
# ______________
# حلة ('حل', 'ة')
# ______________
# انقسم ('انقسم',)
# ______________
# رفع ('رفع',)
# ______________
# اصطحب ('اصطحب',)
# ______________
# وجدوا ('وجد', 'وا')
# ______________
# كان ('كان',)
# ______________
# تمرد ('ت', 'مرد')
# ______________
# يجعلني ('ي', 'جعل', 'ني')
# ______________
# يفتقد ('ي', 'فتقد')
# ______________
# يبدو ('ي', 'بدو')
# ______________
# يوجد ('ي', 'وجد')
# ______________
# يدل ('ي', 'دل')
# ______________
# نفث ('نفث',)
# ______________
# يفكر ('ي', 'فكر')
# ______________
# يوجد ('ي', 'وجد')
# ______________
# يوجد ('ي', 'وجد')
# ______________
# يبدو ('ي', 'بدو')
# ______________
# تفتح ('ت', 'فتح')
# ______________
# تفتح ('تفتح',)
# ______________
# أمرت ('أمر', 'ت')
# ______________
# أمرت ('أمر', 'ت')
# ...

# %%
# nouns MSA
for word in txt_ARB.split():
    for pat in patterns_n:
        match = re.search(pat[0], word)
        if match: 
            if match.group(pat[1]) in n_stem:
                    print(word, match.groups())
                    print('______________')
# Out:
# الولد ('ال', 'ولد')
# ______________
# فتح ('فتح',)
# ______________
# فارس ('فارس',)
# ______________
# السيارة ('ال', 'سيارة')
# ______________
# الحجرة ('ال', 'حجرة')
# ______________
# الجانبية ('ال', 'جانبي', 'ة')
# ______________
# الوحيدة ('ال', 'وحيد', 'ة')
# ______________
# للبنك ('ل', 'ل', 'بنك')
# ______________
# رجل ('رجل',)
# ______________
# أصلع ('أصلع',)
# ______________
# حلة ('حل', 'ة')
# ______________
# حلة ('حلة',)
# ______________
# فريق ('فريق',)
# ______________
# المطاردة ('ال', 'مطاردة')
# ______________
# لص ('لص',)
# ______________
# الجميع ('ال', 'جميع')
# ______________
# عيونهم ('عيون', 'هم')
# ______________
# مصدر ('مصدر',)
# ______________
# الدكتور ('ال', 'دكتور')
# ______________
# عالم ('عالم',)
# ______________
# القرن ('ال', 'قرن')
# ______________
# الخامس ('ال', 'خامس')
# ______________
# البريق ('ال', 'بريق')
# ______________
# كل ('كل',)
# ______________
# خطوط ('خطوط',)
# ______________
# الإتصالات ('ال', 'إتصال', 'ات')
# ______________
# ...

# %%
# prepositions MSA
for word in txt_ARB.split():
    for pat in patterns_prep:
        match = re.search(pat[0], word)
        if match: 
            if match.group(pat[1]) in prep_stem:
                    print(word, match.groups())
                    print('______________')
# Out:
# في ('في',)
# ______________
# أمام ('أمام',)
# ______________
# من ('من',)
# ______________
# إلى ('إلى',)
# ______________
# إلى ('إلى',)
# ______________
# إلى ('إلى',)
# ______________
# على ('على',)
# ______________
# عليه ('علي', 'ه')
# ______________
# على ('على',)
# ______________
# في ('في',)
# ______________
# ومن ('و', 'من')
# ______________
# خلال ('خلال',)
# ______________
# على ('على',)
# ______________
# من ('من',)
# ______________
# من ('من',)
# ______________
# في ('في',)
# ______________
# منذ ('منذ',)
# ______________
# على ('على',)
# ______________
# إلى ('إلى',)
# ______________
# من ('من',)
# ______________
# في ('في',)
# ______________
# لديهم ('لدي', 'هم')
# ______________
# من ('من',)
# ______________
# في ('في',)
# ______________
# في ('في',)
# ______________
# إلى ('إلى',)
# ______________
# في ('في',)
# ______________
# في ('في',)
# ______________
# حول ('حول',)
# ______________
# بين ('ب', 'ين')
# ______________
# بين ('بين',)
# ______________
# ...

# %%
# pronouns MSA
for word in txt_ARB.split():
    for pat in patterns_pron:
        match = re.search(pat[0], word)
        if match: 
            if match.group(pat[1]) in Pronouns_stem:
                    print(word, match.groups())
                    print('______________')
# Out:
# ما ('ما',)
# ______________
# ذاك ('ذاك',)
# ______________
# ما ('ما',)
# ______________
# ذلك ('ذلك',)
# ______________
# هذا ('هذا',)
# ______________
# هو ('هو',)
# ______________
# تلك ('تلك',)
# ______________
# التي ('التي',)
# ______________
# هذا ('هذا',)
# ______________
# ذات ('ذات',)
# ______________
# هي ('هي',)
# ______________
# التي ('التي',)
# ______________
# التي ('التي',)
# ______________
# هي ('هي',)
# ______________
# هذا ('هذا',)
# ______________
# التي ('التي',)
# ______________
# التي ('التي',)
# ______________
# الذي ('الذي',)
# ______________
# الذي ('الذي',)
# ______________
# الذي ('الذي',)
# ______________
# التي ('التي',)
# ______________
# الذين ('الذين',)
# ______________
# التي ('التي',)
# ______________
# الذي ('الذي',)
# ______________
# التي ('التي',)
# ______________
# الذي ('الذي',)
# ______________
# التي ('التي',)
# ______________
# التي ('التي',)
# ______________
# التي ('التي',)
# ______________
# التي ('التي',)
# ______________
# ...

# %%
# particles MSA
for word in txt_ARB.split():
    for pat in patterns_particles:
        match = re.search(pat[0], word)
        if match: 
            if match.group(pat[1]) in particles:
                    print(word, match.groups())
                    print('______________')
# Out:
# هل ('هل',)
# ______________
# لقد ('ل', 'قد')
# ______________
# لا ('لا',)
# ______________
# لم ('لم',)
# ______________
# يا ('يا',)
# ______________
# يا ('يا',)
# ______________
# قد ('قد',)
# ______________
# لا ('لا',)
# ______________
# أو ('أو',)
# ______________
# لا ('لا',)
# ______________
# أي ('أي',)
# ______________
# حيث ('حيث',)
# ______________
# لا ('لا',)
# ______________
# أنها ('أن', 'ها')
# ______________
# لم ('لم',)
# ______________
# أي ('أي',)
# ______________
# لم ('لم',)
# ______________
# أن ('أن',)
# ______________
# بينما ('بينما',)
# ______________
# عندما ('عندما',)
# ______________
# قد ('قد',)
# ______________
# بينما ('بينما',)
# ______________
# أنني ('أن', 'ني')
# ______________
# أن ('أن',)
# ______________
# حيث ('حيث',)
# ______________
# أن ('أن',)
# ______________
# قد ('قد',)
# ______________
# إذا ('إذا',)
# ______________
# لم ('لم',)
# ______________
# حيث ('حيث',)
# ______________
# حيث ('حيث',)
# ______________
# ذات ('ذات',)
# ...

# %%
# farsa MSA
import json
import requests

url = 'https://farasa.qcri.org/webapi/segmentation/'
text = txt_ARB
api_key = "jIGVxLtHkXJiJkdIYY"
payload = {'text': text, 'api_key': api_key}
data = requests.post(url, data=payload)
result = json.loads(data.text)
print(result)
# Out:
# {'text': ['هل', 'يرغب', 'ال+ولد', 'في', 'فتح', 'حساب', '؟', 'أوقف', 'فارس', 'ال+سيار+ة', 'أمام', 'ال+بنك', '.', 'لقد', 'جئ+ت', 'ل+ال+سحب', '،', 'لا', 'أرغب', 'ال+مزيد', '.', 'لم', 'تفهم', 'بعد', '،', 'يا', 'رجل', '!', 'اندفع', 'من', 'ال+حجر+ة', 'ال+جانبي+ة', 'ال+وحيد+ة', 'ل+ال+بنك', 'رجل', 'بدين', '،', 'أصلع', 'ال+رأس', '،', 'يرتدي', 'حل+ة', 'أنيق+ة', '.', 'انقسم', 'فريق', 'ال+مطارد+ة', 'إلى', 'نصف+ين', '.', 'ما', 'رأي+ك', '،', 'يا', 'لص', 'ال+بنوك', '؟', 'رفع', 'ال+جميع', 'عيون+هم', 'إلى', 'مصدر', 'ال+صوت', '.', 'اصطحب', 'ال+زائر+ان', 'إلى', 'كوكب+هم', '،', 'وجد+وا', 'مهم+ة', '.', 'كان', 'ال+دكتور', 'عالم', 'ال+قرن', 'ال+خامس', 'قد', 'تمرد', 'على', 'عصر+ه', '.', 'ذاك', 'ال+بريق', 'يجعلني', 'عصبي+ة', '.', 'كل', 'خطوط', 'ال+إتصال+ات', 'مقطوع+ة', '.', 'منزل', 'فخم', 'يفتقد', 'ال+ترتيب', '،', 'باب', 'ال+منزل', 'لا', 'يبدو', 'علي+ه', 'كسر', 'أو', 'محاول+ة', 'اقتحام', '،', 'لا', 'يوجد', 'ما', 'يدل', 'على', 'أي', 'محاول+ات', 'سرق+ة', '.', 'صاحب', 'ال+عنق', 'ال+منحور', '.', 'نفث', 'ال+ضابط'
# ...

# %%
# morphologica analysis ECA
import re
tokens=['حكايتنا', 'اليوم', 'عن', 'سلحفاة', 'كانت', 'بتعيش', 'في', 'غابة', 'مليانة', 'أكل', 
        'يكفي', 'كل', 'الحيوانات', '،', 'كان', 'المميز', 'في', 'الغابة', 'دي', 'ان', 'كان', 'فيه', 'نهر', 
        'كبير', 'اوي', '،', 'النهر', 'ده', 'كانت', 'بتشرب', 'منه', 'بقيت', 'الحيوانات', '،', 'السلحفاة', 
        'كانت', 'طيبة', 'جدا', 'وعشان', 'كدا', 'اتعرفت', 'على', 'حيوانات', 'تانية', '،', 'من', 'الحيوانات',
          'اللى', 'كانت', 'السلحفاة', 'بتحبهم', 'حمامتين', 'جمال', 'جدا', '،', 'جه', 'فترة', 'من', 'الفترات'
          , 'و', 'النهر', 'ده', 'قل', 'بدرجة', 'كبيرة', '،', 'النهر', 'فضل', 'يقل', 'لحد', 'ما', 'اختفى', 'تماما',
            'وبقى', 'عبارة', 'عن', 'ارض', 'ناشفة', '،', 'قررت', 'اغلب', 'الحيوانات', 'انها', 'تسيب', 'المكان', 'ده', 'وتروح', 'لمكان', 'تاني', 'فيه', 'ميه', 'عشان', 'يقدروا', 'يشربوا', 'ويعيشوا', '.', 'الحمامتين', 'قالوا', ':', 'احنا', 'لازم', 'نسيب', 'المكان', 'ده', 'ونشوف', 'اي', 'مكان', 'تاني', 'قريب', 'فيه', 'نهر', 'عشان', 'نشرب', 'والا', 'كدة', 'هنموت', '،', 'سمعتهم', 'السلحفاة', 'وقالت', ':', 'انا', 'كمان', 'مش', 'هقدر', 'اعيش', 'هنا', 'ممكن', 'تاخدوني', 'معاكوا', 'يا', 'صحابي', '،', 'الحمامتين', 'قالوا', ':', 'بس', 'احنا', 'بنطير', 'يا', 'سلحفاة', 'وانتي', 'بتمشي', 'على', 'الارض', '،', 'بصت', 'السلحفاة', 'للارض', 'وكانت', 'حزينة', 'جدا', 'من', 'رد', 'الحمامتين', '،', 'فجأة', 'قالت', 'واحدة', 'من', 'الحمامتين', ':', 'بصي', 'انا', 'عندي', 'فكرة', 'حلوة', 'جدا', 'هتخلينا', 'نقدر', 'نساعدك', 'بس', 'بشرط', '،', 'قالت', 'السلحفاة', ':', 'انا', 'موافقة', 'على', 'الشرط', 'من', 'دلوقتي', 'بس', 'ايه', 'هو', 'الشرط', 'ده', '.', 'قالت', 'الحمامة', ':', 'اوعي', 'مهما', 'حصل', 'تفتحي', 'بؤك', 'او', 'تتكلمي', 'مع', 'اي', 'حد', 'واحنا', 'ماشيين', 'حتى', 'لو', 'حد', 'كلمك', '،', 'قالت', 'السلحفاة', ':', 'تمام', 'مفيش', 'مشكلة', '،', 'السلحفاة', 'قالت', 'كدا', 'وهي', 'مش', 'عارفة', 'ليه', 'ممنوع', 'الكلام', 'يعني', 'بس', 'مش', 'مشكلة', 'المهم', 'بالنسبة', 'للسلحفاة', 'دي', 'انها', 'تمشي', 'من', 'المكان', 'ده', '،', 'واحدة', 'من', 'الحمامتين', 'جابت', 'عود', 'خشب', 'كبير', 'وقالت', 'للسلحفاة', ':', 'عضي', 'العود', 'ده', 'من', 'النص', 'كويس', 'واوعي', 'تفلتيه', 'واحنا', 'هنطير', 'بيكي', 'وزي', 'ما', 'قولنالك', 'اوعي', 'تفتحي', 'بؤك', 'ابدا', '،', 'طار', 'الحمامتين', 'ومعاهم', 'السلحفاة', '.', 'الحيوانات', 'شافت', 'السلحفاة', 'وهي', 'طايرة', 'في', 'السما', '،', 'بدأت', 'الحيوانات', 'تضحك', 'بصوت', 'عالي', 'وتقول', ':', 'ايه', 'ده', 'دي', 'خر', 'نكتة', 'شفناها', 'سلحفاة', 'طايرة', 'في', 'السما', '،', 'السلحفاة', 'ادايقت', 'جدا', 'من', 'تريقة', 'الحيوانات', 'وفتحت', 'بؤها', 'وقالت', ':', 'فيها', 'ايه', 'يعني', 'لما', 'تشوف', 'سلحفاة', 'طايرة', '،', 'السلحفاة', 'مخدتش', 'بالها', 'انها', 'خالفت', 'تعليمات', 'الحمامة', 'و', 'وقعت', 'على', 'شجر', 'و', 'بعديها', 'على', 'الارض', '،', 'اتعورت', 'السلحفاة', 'جامد', 'ولما', 'نزلوا', 'الحمامتين', 'وراها', 'عشان', 'يطمنو', 'عليها', 'قالت', 'السلحفاة', ':', 'انا', 'اسفة', 'جدا', 'انا', 'عرفت', 'دلوقتي', 'ليه', 'كنتو', 'بتحذروني', 'من', 'اني', 'اتكلم', 'و', 'انا', 'طايرة', 'معاكو', 'في', 'السما', '.', 'العم', 'سالم', 'كان', 'راجل', 'فقير', 'جدا', 'وعايش', 'في', 'بيت', 'متكسر', 'و', 'صغير', '،', 'كان', 'العم', 'سالم', 'بيشتكي', 'ديما', 'انه', 'رجل', 'فقير', 'وبيسأل', 'نفسه', 'هو', 'انا', 'امتى', 'هبقى', 'غني', '،', 'العم', 'سالم', 'كان', 'متجوز', 'ومعاه', 'عيال', '،', 'كان', 'ديما', 'العم', 'سالم', 'يروح', 'الشغل', 'الصبح', 'هو', 'شغال', 'في', 'مصنع', 'منسوجات', 'بس', 'مرتبه', 'مش', 'عالي', 'اوي', '،', 'ديما', 'كان', 'كل', 'ما', 'حد', 'يسأل', 'العم', 'سالم', 'انت', 'عامل', 'ايه', 'يرد', 'عليه', 'بحزن', 'وانه', 'ديما', 'محتاج', 'اكل', 'و', 'لبس', 'و', 'مصاريف', 'وهو', 'معهوش', 'فلوس', 'تقضي', 'احتياجات', 'بيته', 'كان', 'الناس', 'ديما', 'بيقولو', 'للعم', 'سالم', 'احمد', 'ربنا', 'غيرك', 'مش', 'لاقي', 'اللي', 'انت', 'فيه', 'ده', '،', 'بس', 'بالرغم', 'من', 'كدة', 'عم', 'سالم', 'مكنش', 'بيبطل', 'شكوى', '،', 'كان', 'ديما', 'بيبص', 'على', 'الناس', 'الاغنيا', 'اللي', 'معاهم', 'فلوس', 'و', 'عربيات', 'ويقول', ':', 'ليه', 'ياربي', 'مخلتنيش', 'واحد', 'غني', 'بدل', 'الهم', 'اللي', 'انا', 'عايش', 'فيه', 'ده', '،', 'في', 'مرة', 'من', 'المرات', 'العم', 'سالم', 'كان', 'مروح', 'من', 'شغله', 'وهو', 'ماشي', 'لمح', 'عربية', 'راكنة', 'على', 'جنب', 'وفيها', 'شخص', 'حاطط', 'ايده', 'على', 'راسه', '،', 'عم', 'سالم', 'قرر', 'انه', 'يروح', 'للراجل', 'ده', 'ويقولو', 'مالك', 'اللي', 'لفت', 'نظر', 'عم', 'سالم', 'ان', 'الراجل', 'كان', 'باين', 'عليه', 'انه', 'غني', 'جدا', '،', 'يا', 'ترى', 'البني', 'ادم', 'لو', 'غني', 'كده', 'ومعاه', 'فلوس', 'كتير', 'هيزعل', 'ليه', '،', 'سأل', 'عم', 'سالم', 'الراجل', 'وقاله', ':', 'مالك', 'يا', 'استاذ', 'زعلان', 'ليه', 'فيه', 'حاجة', '؟', '،', 'رد', 'عليه', 'الراجل', 'الغني', 'وقاله', ':', 'انا', 'لسا', 'جاي', 'من', 'عند', 'الدكتور', 'واكتشفت', 'اني', 'عندي', 'مرض', 'وهموت', 'بعد', 'كام', 'سنة', 'وانا', 'ربنا', 'مرزقنيش', 'باولاد', 'لاني', 'عقيم', '،', 'اتصدم', 'عم', 'سالم', 'لما', 'سمع', 'الكلام', 'ده', 'وقال', 'في', 'نفسه', ':', 'الحمد', 'لله', 'على', 'النعمة', 'اللي', 'انا', 'فيها', 'انا', 'عندي', 'صحة', 'و', 'اولاد', '،', 'من', 'ساعتها', 'عم', 'سالم', 'اتغير', 'وبقى', 'بيحمد', 'ربنا', 'كتير', 'على', 'النعم', 'اللي', 'هو', 'فيها', 'واقتنع', 'فعلا', 'ان', 'فيه', 'ناس', 'نفسها', 'يبقى', 'عندها', 'النعم', 'دي', 'زي', 'الاولاد', 'و', 'الصحة', '.', 'ولكنه', 'لقي', 'السلحفاة', 'صاحبته', 'حزينة', 'جدا', '،', 'سألها', 'عن', 'سبب', 'حزنها', '،', 'فقالت', 'له', ':', 'اتفضل', 'في', 'البيت', 'هنا', '.', 'ولما', 'دخل', 'العصفور', 'بيتها', 'اتصدم', 'من', 'اللي', 'شافه', '،', 'كانت', 'السلحفاة', 'بتجهز', 'خر', 'شنطة', '،', 'وهتسيب', 'المكان', 'كله', 'وتمشي', '.', 'سألها', 'العصفور', 'عن', 'السبب', 'انها', 'ماشية', 'بحزن', '،', 'وجاوبته', 'بحزن', 'أكبر', 'منه', 'قايلة', ':', 'أنا', 'عارفة', 'طبعا', 'قد', 'إيه', 'إنت', 'بتحبني', '،', 'وأنت', 'تعرف', 'إنك', 'صاحبى', 'الوحيد', '،', 'ولكن', 'مش', 'قادرة', 'أعيش', 'في', 'المكان', 'ده', '،', 'المكان', 'كل', 'إجازة', 'بيكون', 'عبارة', 'عن', 'نفايات', 'بسبب', 'يوم', 'واحد', 'في', 'الأسبوع', '،', 'بضطر', 'بعده', 'أنضف', 'لباقي', 'الأيام', 'الستة', '،', 'وما', 'بصدق', 'أنهي', 'ألاقي', 'يوم', 'الإجازة', 'جه', 'من', 'جديد', '،', 'والأطفال', 'رجعوا', 'وخربوا', 'كل', 'شي', '.', 'جه', 'على', 'بال', 'العصفور', 'فكرة', '،', 'جاب', 'شوية', 'ورق', 'وكتب', 'عليهم', 'بعض', 'العبارات', 'عن', 'النظافة', 'والحفاظ', 'عليها', 'وعلقها', 'على', 'الشجر', '،', 'ولكن', 'جه', 'الأطفال', 'وقطعوا', 'الورق', 'ولعبوا', 'بيه', 'كمان', '.', 'مشيت', 'السلحفاة', 'وراحت', 'عند', 'أختها', '،', 'وبعد', 'أسبوع', 'رجعوا', 'الأطفال', 'ولقيوا', 'المكان', 'مليان', 'بالروايح', 'المميتة', '،', 'فنضفوا', 'المكان', 'بنفسهم', '،', 'وتركوه', 'نضيف', 'بعد', 'العطلة', '.', 'فرح', 'العصفور', 'وراح', 'للسلحفاة', 'وحكالها', 'اللي', 'حصل', 'من', 'الأطفال', '،', 'فرجعت', 'معاه', 'ومن', 'بعدها', 'ارتاحت', 'من', 'شقاوة', 'الأطفال', 'اللي', 'أخيرا', 'اتعلموا', 'الدرس', 'وفهموا', 'المعنى', 'الحقيقي', 'للنظافة', '.', 'جاسر', 'ولد', 'مؤدب', 'وبيسمع', 'كلام', 'مامته', '،', 'وفي', 'يوم', 'من', 'الأيام', 'طلب', 'جاسر', 'من', 'مامته', 'أنه', 'يروح', 'السوق', 'ويشتري', 'لها', 'كل', 'الطلبات', 'اللي', 'هي', 'عايزاها', 'من', 'هناك', '،', 'قال', 'لها', ':', 'ماما', 'ماما', 'هو', 'أنا', 'مش', 'خلاص', 'بقيت', 'كبير', '؟', '!', 'فرد', 'عليها', 'جاسر', 'وقال', 'لها', ':', 'أنا', 'هروح', 'السوق', 'وأخفف', 'عنك', 'شوية', '،', 'ما', 'تقلقيش', 'يا', 'ماما', 'هجيبلك', 'كل', 'اللي', 'انتي', 'محتاجاه', '.', 'مامة', 'جاسر', ':', 'يا', 'جاسر', 'لازما', 'تخلي', 'بالك', 'من', 'نفسك', '،', 'وتخلي', 'بالك', 'من', 'العربيات', 'أنت', 'وبتعدي', 'الشارع', '،', 'وإوعى', 'تغيب', 'عني', 'يا', 'حبيبي', '،', 'تشتري', 'الحاجة', 'وترجع', 'لي', 'بسرعة', '،', 'اتفقنا', '؟', '!', 'جاسر', ':', 'طبعا', 'اتفقنا', 'يا', 'ماما', '،', 'أول', 'ما', 'أخلص', 'هرجع', 'لحضنك', 'على', 'طول', 'يا', 'حبيبتى', '.', 'راح', 'جاسر', 'السوق', '،', 'واشترى', 'كل', 'حاجة', 'لمامته', '،', 'ورجع', 'بسرعة', '.', 'مامته', 'كانت', 'فرحانة', 'جدا', 'بيه', '،', 'وأخيرا', 'ابنها', 'كبر', 'وماعدش', 'صغير', '،', 'وبقي', 'ما', 'يتخافش', 'عليه', '.', 'وكل', 'يوم', 'بقي', 'جاسر', 'يروح', 'السوق', 'بدل', 'مامته', '،', 'ولكن', 'في', 'يوم', 'اتأخر', 'جاسر', 'فيه', 'جدا', '،', 'اتأخر', 'لدرجة', 'أن', 'مامته', 'نزلت', 'من', 'بيتها', 'وفضلت', 'تدور', 'عليه', 'وتسأل', 'صحابه', 'واحد', 'واحد', '،', 'بس', 'ولا', 'واحد', 'منهم', 'عارف', 'جاسر', 'راح', 'فين', '.', 'وبكدة', 'مامته', 'كانت', 'قلقانة', 'عليه', 'وكانت', 'هتموت', 'من', 'كتر', 'الرعب', 'والخوف', 'عليه', '،', 'وصحابه', 'راحوا', 'معاها', 'وفضلوا', 'كلهم', 'يدورا', 'على', 'جاسر', '،', 'هو', 'راح', 'فين', 'بس', 'يا', 'ربي', '؟', '!', 'وكل', 'ما', 'يسألوا', 'حد', 'في', 'الشارع', 'أو', 'السوق', 'يسيب', 'كل', 'حاجة', 'ويفضل', 'يدور', 'معاهم', '،', 'كلهم', 'خافوا', 'على', 'جاسر', 'وخافوا', 'على', 'مامته', 'إللي', 'كانت', 'مش', 'مبطلة', 'عياط', '.',
        'أومال', 'جاسر', 'فين', 'بقي', 'جاسر', 'هو', 'وفي', 'السوق', 'لقي', 'صحابه', 'اللي', 'معاه', 'في', 'المدرسة', 'وكانوا', 'يومها',
        'عايزين', 'يلعبوا', 'كورة', 'معاه', 'جاسر', 'أكتر', 'حاجة', 'بيحبها', 'ومش', 'بيقدر', 'يقاومها', 'هي', 'الكورة', 'فراح', 'معاهم', 
        'وقال', 'في', 'نفسه', 'دور', 'واحد', 'مش', 'هيخليني', 'أتأخر', 'على', 'ماما', 'وبكدة', 'ماما', 'مش', 'هتقلق', 'عليا”', 'بس', 'هو', 
        'ماكنش', 'يعرف', 'إن', 'الدور', 'هيجر', 'دور', 'وراه', 'وهيخلي', 'مامته', 'تدور', 'عليه', 'في', 'الشوارع', 'زي', 'المجنونة', 'ومرة', 
        'واحدة', 'وهو', 'وصحابه', 'كانوا', 'بيلعبوا', 'كورة', 'سمع', 'أصوات', 'ناس', 'كتيرة', 'بتنادي', 'عليه', 'باسمه', 'بصوت', 'عالي', 'ولما', 
        'راح', 'يشوفهم', 'لقي', 'مامته', 'عمالة', 'تبكي', 'والدموع', 'عمالة', 'تنزل', 'على', 'خدودها', 'جري', 'ناحية', 'مامته', 'وحضنها',
        'بشدة', 'وقال', 'لها', 'مالك', 'يا', 'ماما', 'انتي', 'بتعيطى', 'ليه', 'علشان', 'أنا', 'أتأخرت', 'عليكي', 'سامحيني', 'يا', 
        'ماما', 'أنا', 'مكنتش', 'أعرف', 'إني', 'هتأخر', 'بالطريقة', 'دي', 'أنا', 'قلت', 'في', 'نفسي', 'دور', 'واحد', 'مع', 'صحابي', 'وهرجعلك',
        'بسرعة', 'سامحيني', 'يا', 'ماما', 'مامته', 'ساعتها', 'ماعرفتش', 'تعمل', 'ايه', 'تفرح', 'بسلامته', 'ولا', 'تلومه', 'وتعاقبه', 'أنه', 
        'اتأخر', 'عنها', 'خدته', 'فى', 'حضنها', 'وفضلت', 'تبكي', 'كتير', 'مامته', 'جاسر', 'انت', 'عارف', 'أنك', 'الحاجة', 'الحلوة', 
        'الوحيدة', 'في', 'حياتي', 'بعد', 'وفاة', 'والدك', 'لازم', 'تعرف', 'الحاجة', 'دي', 'كويس', 'يا', 'ابني', 'وإني', 'من', 'أقل', 'حاجة',
        'عليك', 'قلبي', 'بيوجعني', 'يا', 'حبيبي', 'وكل', 'الناس', 'اللي', 'معاها', 'طمنوها', 'عليه', 'وقالوا', 'لها', 'تاني', 'مرة', 
        'مينزلش', 'جاسر', 'الا', 'وهي', 'لأنه', 'مهما', 'كبر', 'هو', 'برده', 'لسه', 'صغير', 'هو', 'عنده', 'سبع', 'سنين', 'بس', 'وما', 'ينفعش', 'كل', 'اللي',
        'يقولها', 'عليه', 'تنفذه', 'الحاجة', 'الكويسة', 'والصالحة', 'ليه', 'تعملها', 'له', 'أما', 'الحاجة', 'اللي', 'هتضره', 'وتضرها',
        'فبلاش', 'منها', 'والطيب', 'أحسن؛', 'لأنها', 'في', 'لحظة', 'واحدة', 'الكل', 'اعتقد', 'انها', 'فقدته', 'للأبد', 'والكل', 'افتكر', 'ان',
        'حاجة', 'وحشة', 'حصلت', 'له', 'جاسر', 'اتعلم', 'الدرس', 'وبقي', 'كل', 'يوم', 'ينزل', 'مع', 'مامته', 'ويشتري', 'كل', 'حاجة', 'معاها', 
        'ويسمع', 'كلامها', 'كاه', 'وما', 'يقلقهاش', 'عليه', 'خالص', 'كان', 'فيه', 'ضفدع', 'صغير', 'اسمه', 'فرفور', 'فرفور', 'كان', 'عايش', 
        'في', 'بركة', 'مية', 'صغيرة', 'مع', 'باقي', 'الضفادع', 'لكنه', 'كان', 'مختلف', 'شوية', 'دايمًا', 'عنده', 'فضول', 'وبيحب', 'يكتشف', 
        'كل', 'حاجة', 'حواليه', 'يوم', 'من', 'الأيام', 'وهو', 'قاعد', 'جنب', 'البركة', 'سمع', 'صوت', 'غريب', 'جاى', 'من', 'الغابة', 'قال', 
        'لنفسه', 'إيه', 'الصوت', 'ده', 'لازم', 'أروح', 'أشوف', 'الضفادع', 'التانية', 'قالتله', 'يا', 'فرفور', 'أوعى', 'تبعد', 'عن', 
        'البركة', 'الغابة', 'مليانة', 'مخاطر', 'خلى', 'بالك', 'لكن', 'فرفور', 'كان', 'عنيد', 'وقال', 'مفيش', 'حاجة', 'تخوف', 'أنا', 
        'شجاع', 'وهعرف', 'أرجع', 'بسرعة', 'وفعلاً', 'دخل', 'الغابة', 'وهو', 'بيتنطط', 'من', 'شجرة', 'لشجرة', 'لحد', 'ما', 'لقى', 'بحيرة', 
        'صغيرة', 'مليانة', 'ورد', 'لونه', 'أزرق', 'وجميل', 'مبسوط', 'جدًا', 'قرر', 'يقعد', 'شوية', 'جنب', 'المية', 'فجأة', 'خرج', 'طائر', 
        'كبير', 'وقاله', 'إنت', 'مين', 'وبتعمل', 'إيه', 'هنا', 'فرفور', 'خاف', 'في', 'الأول', 'لكن', 'بعدين', 'قال', 'أنا', 'فرفور', 
        'شفت', 'المكان', 'ده', 'وعجبني', 'فقررت', 'أستكشفه', 'الطائر', 'ضحك', 'وقال', 'انت', 'شجاع', 'يا', 'ضفدع', 'صغير', 'لكن', 'خليك', 
        'عارف', 'إن', 'الغابة', 'دي', 'مش', 'كل', 'حاجة', 'فيها', 'جميلة', 'زي', 'البحيرة', 'دي', 'دايمًا', 'خلي', 'بالك', 'فرفور', 'قال', 
        'للطائر', 'شكرا', 'جدا', 'انك', 'بتحذرنى', 'ورجع', 'البركة', 'بتاعته', 'لما', 'شافوه','الضفادع', 'قالوله', 'إنت', 'رجعت', 
        'مكنتش', 'خايف', 'قالهم', 'فرفور', 'آه', 'كنت', 'خايف', 'شوية', 'بس', 
        'اكتشفت', 'حاجات', 'جميلة', 'واتعلمت', 'إني', 'لازم', 'أكون', 'حذر', 
        'وأنا', 'باكتشف', 'ومن', 'يومها', 'بقي', 'فرفور', 'مثال', 
        'للضفدع', 'اللي', 'عنده', 'شجاعة', 'وذكاء', 'وكل', 'الضفادع', 'كانت', 'بتقول', 'حكايته', 
        'لكن', 'يوم', 'من', 'الأيام', 'حصلت', 'مصيبة', 'جات', 'سلحفاة', 'كبيرة', 'ووقعت', 'في', 'البركة', 
        'وماعرفتش', 'تخرج', 'السلحفاة', 'كانت', 'بتصرخ', 'وتطلب', 'المساعدة', 'والضفادع', 'كلها', 'كانت',

        'خايفة', 'تقرب', 'منهافرفور', 'قال', 'مش', 'معقول', 'أسيبها', 'كدة', 'تط', 'في', 'الميه', 'وبدأ',
          'يسبح', 'بخوف', 'لكنه', 'كل', 'ما', 'يقرب', 'من', 'السلحفاة', 'كان', 'يحس', 'إنه', 'أقوى', 'في', 'الآخر', 
          'وصل', 'ليها', 'وساعدها', 'تطلع', 'من', 'البركة', 'مبدئيا', 'اللي', 'مستني', 'ابهار', 'زي', 'الفيل', 'الازرق', 
          'ميقراش', 'أحسن', 'احمد', 'مراد', 'تخطى', 'مرحلة', 'ان', 'القارئ', 'يخلص', 'الرواية', 'وهو', 'فاتح', 'بؤه', 'لمرحلة', 

          'ان', 'القارئ', 'يخلص', 'الرواية', 'وهو', 'محترم', 'الكاتب', 'اتقان', 'مخيف', 'بصرف', 'النظر', 'عن', 'اخطاء', 'لا', 'تذكر', 
          'ف', 'الحوار', 'انما', 'احمد', 'مراد', 'سافر', 'عاش', 'حبة', 'ف', 'اوائل', 'القرن', 'العشرين', 'وجه', 'ياخدنا', 'لهناك', 
          'خلطة', 'مشاعر', 'انسانية', 'حقيقية', 'لدرجة', 'غريبة', 'دراما', 'نقلته', 'من', 'كاتب', 'شاب', 'بيستعرض', 'لصنايعي', 'حقيقي', 
          'تثق', 'فيما', 'سيكتب', 'بعد', 'كده', 'مبدأيا', 'الرواية', 'اكثر', 'من', 'رائعة', 'و', 'للناس', 'الى', 'بيقولوا', 'ان', 

          'مالهاش', 'هدف', 'انا', 'شايفة', 'غير', 'كدا', 'تماما', 'الهدف', 'منها', 'فى', 'رأيي', 'هو', 'توعية', 'الناس', 'عن', 'مرض', 
          'التوحد', 'و', 'الجهل', 'بالمرض', 'ده', 'بيخلي', 'الناس', 'تفتكر', 'ان', 'الطفل', 'ده', 'ممسوس', 'او', 'حاجة', 'و', 'مش', 'بيعملوا', 
          'الطفل', 'معاملة', 'كويسة', 'روايه', 'حلوة', 'اوي', 'عيشتني', 'في', 'حاله', 'غريبة', 'كنت', 'حاسه', 'اني', 'مع', 'ابطال', 'كل', 
          'قصة', 'عايشة', 'معاهم', 'حاسه', 'بيهم', 'شيفاهم', 'اودامي', 'في', 'قصص', 'حسيتها', 'انا', 'اوي', 'كانها', 'بتتكلم', 'عني', 'عن', 
          'مشاعري', 'عن', 'ظروف', 'مريت', 'بيها', 'عن', 'خوفي', 'بجد', 'استمتعت', 'وهو', 'عم', 'نجيب',
        'يتكتب', 'فيه', 'ريفيو', 'برضو', 'بالذمه', 'شئ', 'مرعب', 'أنك', 'تشوف', 'نهايتك', 'تعيشها', 'كل', 'يوم', 'وتعيش', 
        'آلامها', 'شئ', 'مرعب', 'انك', 'تكون', 'عارف', 'حبايبك', 'هيموتوا', 'ازاي', 'في', 'اللحظات', 'دي', 'الجهل', 'مفيد', 'اكتر', 'من', 'المعرفه', 'هل', 'تعرف', 'محمود', 'السمنودي', 'فلتحمد', 'الله', 'انك', 'لا', 'تعرفه', 'فسألها', 'خالد', 'على', 'الفور', 'طب', 'ليه', 'أنتى', 'مش', 'ملازمة', 'الأسرة', 'الحاكمة', 'طول', 'الوقت', 'ردت', 'أسيل', 'لقد', 'طلب', 'منى', 'الحاكم', 'ذلك', 'بالفعل', 'ولكننى', 'رفضت', 'خالد', 'فى', 'دهشة', 'رفضتي', 'أجابته', 'أسيل', 'مبتسمة', 'نعم', 'لا', 'أريد', 'أن', 'أكون', 'أسيرة', 'لمكان', 'بعينه', 'حتى', 'لو', 'كان', 'الحاكم', 'خالد', 'ومازال', 'مندهشا', 'تقدرى', 'ترفضى', 'طلب', 'للحاكم', 'أسيل', 'إنه', 'حقى', 'ولدى', 'من', 'الحرية', 'ما', 'يجعلنى', 'اتحكم', 'بإرادتى', 'وأنا', 'أحب', 'الانطلاق', 'لا', 'أريد', 'أن', 'يقيدنى', 'أحد', 'صمت', 'خالد', 'ثم', 'سألها', 'سؤالا', 'جال', 'بخاطره', 'هو', 'نظام', 'الحكم', 'هنا', 'فى', 'زيكولا', 'ملكى', 'ردت', 'أسيل', 'لا', 'إن', 'حاكم', 'زيكولا', 'يظل', 'بالحكم', 'خمس', 'سنوات', 'ثم', 'يأتى', 'حاكم', 'غيره', 'يختاره', 'أهل', 'زيكولا', 'فاندهش', 'خالد', 'كثيرا', 'خمس', 'سنوات', 'بس', 'أسيل', 'نعم', 'خالد', 'ومفيش', 'تجديد', 'أسيل', 'لا', 'كل', 'حاكم', 'له', 'خمس', 'سنوات', 'فقط', 'ألا', 'تكف', 'تلك', 'المدة', 'أرى', 'أنها', 'كافية', 'لكل', 'حاكم', 'هنا', 'كى', 'يأتى', 'غيره', 'ويكمل', 'مسيرة', 'التقدم', 'لزيكولا', 'ويستفيد', 'من', 'أخطاء', 'من', 'سبقه', 'ولهذا', 'زيكولا', 'تتقدم', 'عن', 'البلاد', 'الأخرى', 'ألستم', 'كذلك', 'فى', 'بلدك', 'ضحك', 'خالد', 'ثم', 'فرك', 'شعره', 'وصمت', 'وحاول', 'أن', 'يختلق', 'موضوعا', 'آخرا', 'للنقاش', 'ثم', 'حدث', 'نفسه', 'أنا', 'دلوقت', 'متأكد', 'إن', 'زيكولا', 'ليست', 'لها', 'أى', 'صلة', 'بالوطن', 'العربى', 'إلا', 'اللغة', 'العربية', 'الرواية', 'عجبتني', 'جدا', 'بس', 'ليا', 'تعليقين', 'اسلوب', 'القصة', 'حسيته', 'مش', 'ادبي', 'بالشكل', 'الكافي', 'فكان', 'فيه', 'غلطات', 'و', 'ده', 'اظنه', 'راجع', 'لفكرة', 'ان', 'حسن', 'كمال', 'مشواره', 'ف', 'الروايات', 'مش', 'كبير', 'وانه', 'كاتب', 'مقالات', 'اكثر', 'من', 'روائي', 'بس', 'صراحة', 'روايته', 'وهمية', 'و', 'تجربة', 'مهمة', 'كتاب', 'رائع', 'جدا', 'هلكني', 'ضحك', 'زعلت', 'جدا', 'ان', 'الكتاب', 'خلص', 'وقريتو', 'اكتر', 'من', 'مرة', 'من', 'الروايات', 'اللى', 'كنت', 'مفكرها', 'رواية', 'عادية', 'بس', 'طلعت', 'رواية', 'بتحمل', 'حاجات', 'حلوة', 'وعظيمة', 'جدا', 
        'مش', 'قادرة', 'أتخيل', 'انى', 'استحملت', 'اقراها', 'ومش', 'قادرة', 'أوصفلك', 'وجعت', 'قلبى', 'قد', 'ايه', 'بجد', 'أسلوب', 'كتابة'
        ,'رائع', 'خيال', 'مالوش', 'حدود', 'وحزن', 'فظيع', 'عجبتنى', 'بقدر', 'ماوجعت', 'قلبى', 'بالظبط']

particle_stem=['كل','في','دي','ان','ده','من','على','اللى','و','لحد','تماما','عن','اغلب','معا','اوي','امتى',
               'عشان','اي','والا','كدة','كمان','مش','هنا','ممكن','مع','يا','بس','انتي','انا','عند','ايه','هو','مهما','او',
               'حتي','لو','كدا','هي','ليه','ب','زي','ابدا','خر','ورا','لما','جدا','بعد','امتي','حتى','مرة','بعض',
                'ما','انت','غير','اللي','جنب', 'إللي','أو','فين','لا','أن','لكن','بدل','بيه', 'له','إنت','علي',
                'طول','طبعا','لي','لها','أنا','هناك','كده','لسا', 'كام','لان','قد', 'إيه', 'أنت',
                 'إنك','جه','مالك','أنهي','فعلا'  ,  'هو', 'في', 'على', 'من', 'إلى', 'أن', 'إني', 'إن', 'مع', 'عن', 'لا', 'أومال','فين','إلا',
    'اللي', 'بلاش', 'كل','لحد', 'بعد', 'زي', 'مش', 'مفيش', 'لكن','مين','مرة','ما',"إيه",'فجأة',
    'لما', 'ما', 'إنه', 'ل', 'و', 'إذا', 'خلى', 'ومع', 'غير', 'دايمًا','مالوش','دي','له','أما','ب','ك','ل','علي','مفيش',
    'ه','عند','بس', 'انى', 'قد ', 'بجد','ايه','فيه','جدا','ألستم','لقد','اوي','مالهاش','مبدأيا','أكون','دايما','حوالي']


nounstem= [ 'جاسر','فرفور', 'جميلة','ناحية','حاجة','ذمه','ريفيو','حدود','خالد','نهاية','ضفدع','قلب',
           'شئ','ضفدع','آلام','مدرسة','يوم','طيب','حكاية',
           'فظيع', 'أومال', 'جاسر', 'صحاب', 'المدرسة', 'كورة', 'ماما', 'شوارع', 'دموع', 
            'خدود', 'قلب', 'ناس', 'قلب', 'جولة', 'ضفدع', 'بركة', 'مية', 'غابة', 'صوت', 
             'طائر', 'بحيرة', 'ورد', 'شجرة', 'فكرة', 'خوف', 'سلحفاة', 'ميه', 'مكان', 
    'فكرة', 'مشاعر', 'تعبير', 'كتابة', 'خيال', 'حزن', 'قلب','مثال','رائع','السوق','قارئ','فيل','ازرق',
    'سلام','سرعة', 'نفس','طريق','اسم','كتير','أصوات','مجنون','مامت','واحد','دور','صاحب', 'أسمه','مياه', 'حياة', 'مخاطر', 'مرض','توحد',
            'خدود', 'قلب', 'ناس', 'قلب', 'جولة', 'ضفدع', 'بركة', 'مية', 'غابة', 'صوت','تاني','نفس',
             'طائر', 'بحيرة', 'ورد', 'شجرة', 'فكرة', 'خوف', 'سلحفاة', 'ميه', 'مكان','أزرق',"سؤال"
                'لحظة', 'حكاية', 'عيشة', 'خوف', 'مشاعر',  'قصة', 'لحظة', 'أسلوب','والد','ابن','أقل','حبيب',
   'سبع','سنين','بلاش','للأبد','كلام','قلق','خالص','باقي','ضفادع','أيام','رواية', 'حاجات',  'كتابة',
   'دمع', 'بيت', 'وقت', 'طفل', 'مرحلة', 'مدينة', 'الله','محمود','معرفة','جهل','حبايب','النظر','صنايع','شاب','كاتب','اوائل',
    'بحير', 'مكان', 'مساعد', 'حيوان', 'هواء','خاطر','عين','أسر','عم','قصص','أبطال','هدق','درجة','مشاعؤ','خلطة','عشرين','قرن','مراد','احمد','حوار',
    'ركض', 'تعليم', 'حياة', 'تجربة', 'زمن', 'رؤية', 'ظرف', 'لحظة','لون','شجر','درس',
    'عالم', 'تحدي', 'قوة', 'أمل','روائي','ادب','اسلوب','تعليق','عرب','لغة','زيكولا','موضوع','نقاش','شعر','مدة','حاكم','سنوات','خمس','أسيل','نظام'
    ,'ظروف','نجيب','أول','آخرا','آلام','اخطاء',"أخطاء",'بؤه',
     'حكايت','يوم','سلحفاة','غابة', 'حيوان','مميز','نهر','طيب','جدا','عشان', 'كدا','شارع','حبيبتى',
        'حمام','فترة','درجة','اختفي','عبارة','ارض','فترات','معاك','ادايق','ربي','ساعت',
        'مكان','ميه','احنا','قريب','صحاب','واحدة','فكرة','شرط','موافق','دلوقتي',
        'بؤك','حد','تمام','مشكلة','ممنوع','يعني','مهم','نسبة','عود','خشب','نص', 'سما','صوت','نكتة','طايرة',
        'تريق','بؤ' ,'تعليم','شجر','عم', 'سالم', 'راجل', 'حمامة','اسف','نظافة','اغنيا', 
        'بيت', 'رجل', 'عيال', 'مصنع', 'نسج','صغير','ديما','نفسه','غني','متجوز','شغل','صبح','منسوج','مرتبه','شكوي','بدل',
        'حزن','اكل','لبس','مصاريف','فلوس','احتياج','ناس','احمد','رب','رغم','عربيات','واحد','هم','مره','مرات','عربية',
        'شخص','ايد','راس','بني','ادم', 'مامت','جاسر','حاجة', 'الشارع','سوق','كتر','ولا','عبارات',
        'ابن','سرعة','حبيبتي','أول','ماما','حضن','نفس','العربيات','حبيبي','فرد','شوية','مامة','خلاص','أيام','طلب',
        'كتير','استاذ', 'زعلان','مالك','دكتور','مرض','سنة','اولاد','كلام','نعم','لله','ساعة','صحة','صاحب','سبب','عصفور','شنط','أكبر','وحيد','إجازة','نفايات','أسبوع', 'صدق','ستة','أطفال','شي','ورق', 
         'حفاظ','أخت','روايح','عطل','فرح','أخيرا','شقاوة','معنى','درس','حقيقي','ولد',   
        'نظر','باقي','باين','بال' ,"حمامه"]

adjectives = ['كويسة','فاتح','مميت','عادي','ناشف', 'حلوة','كبير','عظيم', 'مليانة', 'رائع', 'فظيع','وفي', 'عايزين', 'أكتر', 'معاهم','معقول','ضبط','رائع',
              'رائع','فعلا','وفعلاً','حذر', 'شجاع','كويس','تمام','اتقان','أقوى','مصيبة','كبير','مليان','عنيد','خالص','وحش','كبر',
              'وحيد','بإرادتى','جدًا ','جميل', 'عالي', 'خايف', 'مختلف', 'مبسوط',  'فظيع', 'صغير', 'ذكي', 'محترم',  'غريب', 'حزين','خوف','رعب', 
              'رائعة','مرعب','ممسوس','معاملة','دراما','غريب', 'فظيع', 'رائعة','مفيد', 'سعيد', 'مخلص', 'طموح','تاني','سبق','إنطلاق','إرادت','بتسم','ملازم','حاله','حلو','حقيقي',
              'قوي', 'بسيط', 'كريم', 'هادئ', 'وفي','فرحانة','حلوة','كويس','جامد','عالي','فقير','قلقانة','مليان','عقيم','جديد','مؤدب','راكنة',
              'مرتب', 'عظيم', 'واضح','حكمة','فضول','طيب','صالح','شجاع', 'هدوء','أحسن','زعل','وهم','غلط','كافي','شكل','أكد']

verbstem=['بقي','تعلم','عارف','لقي', 'كان', 'عايز', 'لعب', 'يحب', 'قدر', 'قاوم','عجب','يأتى','جمال',
    'دور', 'خلي', 'أتأخر', 'قلق', 'يعرف','قول','اخد','عاش','تذكر','صرف','محترم','يقرا','سيب','جات','ضحك'
    'جر', 'سمع', 'نادي', 'راح', 'شوف', 'جري','حمد','يموت','مر','حسيت','فتكر','ابهار','ستن','خرج','قرر','قعد','لقى',
    'حضن', 'قال', 'عيط', 'سامح', 'أعرف', 'اتأخر', 'قل', 'رجع', 'فرح','عاقب', 'خدت', 'فضل','عمل','شتري','ختلف',
    'عليه', 'تكمل', 'لها', 'نط','ساعد', 'طلع', 'سبح','طلب','إزاي','استمتع','وعي','ثق','دخل','رجع','علم','ضر',
    'قرب', 'حس', 'وصل', 'سأل','حاول', 'يختلق','فرك', 'صمت','وجد','شيفا','شايف','حاس','انسانية','كتشف','لازم','شفت','استكشف',
    'عمل','رفض','تكفى','عرف','عيش','عجب','لوم','تأخر','وفاة','لازم','طمن','وجع','نزل','قول','نفذ','اعتقد','فقد','افتكر','حصل',
    'يشتري','سمع','عايش','يكتشف','قاعد','استكشاف','قري','فكر','هلك','حدث','فرك','قدم','دهش','يختار','ظل','حكم','رد','حب','قيد','عايز','أريد',
    'لدي','كان','عيش','أكل','كفي','شرب','بقي','عرف','حب','ج','قل','فضل','بقى','قرر','سيب','روح','عايش','مكن','خالف','احتياج',
           'قدر','قادر','قال','لزم','شوف','موت','سمع','اخد','طير','مشي','بص','رد','خلي','ساعد','وعي','حصل','فتح','شكوى','اكتشف',
           'كلم','عارف','جاب','عض','فلت','قول','طار','شاف','بدأ','ضحك','شف','قلق','جيب','دخل','كون','علق','ضيف','ترك',
            'خد', 'خلف','طمن','وقع', 'عور', 'نزل', 'حذر', 'عاش','كسر','كتب','حكا','كن','بطل','خلت','عد','جاي','رزق','اقتنع','شتر',
            'شتكي','سأل','شغال','عامل','يرد','محتاج','قضي','لاقي','ماشي','لمح','حاطط','خاف','قطع','فهم','علم','اتغير', 'شتري',
            'لفت','تري','عيط','دور','راح','تأخر','كبر','فرح','شري','رجع','اتفق','خلص','عدي','غيب','خفف','عايز','ارتاح','عايزا','دورا',
            'طلب','زعل','كشف','صدم','حمد','قنع','لقي','جهز','جاوب' ,'قايل','سبب','نضف','ضطر','خرب','لعب','غير']

prepositions = ['إنت', 'آه','وراه','حواليه','جنب','أنا','بـ', 'قد', 'بالظبط','دلوقت','بكرة','امبارح','هنا','انهارده','اخرى','مازال','بالفعل','ذلك',' على الفور','اودام','بيهم']

verbstem = list(set(verbstem))
nounstem = list(set(nounstem))
prepositions = list(set(prepositions))
particle_stem = list(set(particle_stem))
Adjectives = list(set(adjectives))

print('no. of verb stems: ', len(verbstem))
print('no. of noun stems: ', len(nounstem))
print('no. of prepositions: ', len(prepositions))
print('no. of particles: ', len(particle_stem))
print('no. of adjectives: ', len(adjectives))



colloq_proclitic=['ل','ب','ف','و','س','ك']
# Define prefixes, suffixes, and enclitics
colloq_prefix = ['أ', 'ب', 'ي', 'مست', 'ات', 'بي', 'بت', 'ح', 'ه', 'ع', 'مِ','است', 'ن', 'ا','ما', 'ال','وب','وبت','وبي','ت','م']
colloq_suffix = ['ون','ه', 'ت', 'ة', 'نى', 'ات', 'ين', 'ك', 'نا', 'وا', 'تي', 'كى', 'ها', 'تش', 'كم', 'ى',"اه", 'ش', 'ون','ي','و','ات','ني','لك']
colloq_enclitics = ['ه', 'كم', 'هم', 'نا', 'ها', 'ك', 'كى','ي','لها']
proclitic_par=['و','ب']
pro_def=['ال']


proclitic_pattern='|'.join(colloq_proclitic) 
prefix_pattern = '|'.join(colloq_prefix)  # Join prefixes with OR
suffix_pattern = '|'.join(colloq_suffix)  # Join suffixes with OR
enclitic_pattern = '|'.join(colloq_enclitics)  # Join enclitics with OR

eca_pattern = (
    r'^(?P<proclitics>(' + proclitic_pattern + r')?و|ال)?' 
    r'(?P<prefix>(' + prefix_pattern + r')*)?'            
    r'(?P<stem>.*)'                                
    r'(?P<suffix>(' + suffix_pattern + r')*)?'            
    r'(?P<enclitic>(' + enclitic_pattern + r')*)?$'       
)
# Compile the pattern for efficient reuse
eca_regex = re.compile(eca_pattern)

# Apply the pattern and print results
patterns_particle=[
            (r"^("+"|".join(proclitic_par)+")" + "(.+?)$",2),
            (r"^(.+?)" + "("+"|".join(colloq_suffix)+")$",1),  
            (r"^(.+?)" + "("+"|".join(colloq_enclitics)+")$",1),
            (r"^("+"|".join(proclitic_par)+")"+"("+"|".join(proclitic_par)+")"+"(.+?)$", 3),
            #(r"^("+"|".join(proclitics)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
            (r"^("+"|".join(proclitic_par)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 2),
            (r"^(.+)",1)
            ]
unhandledwordse=[]
print(60 * '==')
print("Mathod 1: \n")
for word in tokens:
    if word in particle_stem:
        print('word:', word, 'is a particle')
    for pat in patterns_particle:
        match=re.search(pat[0],word)
        if match:
            if match.group(pat[1])in particle_stem:
                print(word, match.groups())
    else:
        match = eca_regex.match(word)
        if match:
            if match.group('stem') in verbstem:  # Verb handling
                print(f'V Word is: {word}')
                print('  Proclitics:', match.group('proclitics') or 'None')
                print('  Prefix:', match.group('prefix') or 'None')
                print('  Stem:', match.group('stem'))
                print('  Suffix:', match.group('suffix') or 'None')
                print('  Enclitic:', match.group('enclitic') or 'None')

            elif match.group('stem')  in  nounstem:  # noun handling
                print(f'N Word is : {word}')
                print('  Proclitics:', match.group('proclitics') or 'None')
                print('  Prefix:', match.group('prefix') or 'None')
                print('  Stem:', match.group('stem'))
                print('  Suffix:', match.group('suffix') or 'None')
                print('  Enclitic:', match.group('enclitic') or 'None')
            
            elif match.groups('stem')  in adjectives:  # adj handling
                print(f'adj Word is : {word}')
                print('  Proclitics:', match.group('proclitics') or 'None')
                print('  Prefix:', match.group('prefix') or 'None')
                print('  Stem:', match.group('stem'))
                print('  Suffix:', match.group('suffix') or 'None')
                print('  Enclitic:', match.group('enclitic') or 'None')
        else:
            print(f'word: {word} is unable to be analyzed')
print(60 * '==')
print("Mathod 2: \n")
patterns_verbs=[(r"^("+"|".join(colloq_prefix)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)$", 3),
                (r"^("+"|".join(colloq_proclitic)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)$",3),
                (r"^("+"|".join(colloq_prefix)+")" + "(.+?)" + "("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_enclitics)+")$", 2),
                (r"^("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 2),
                (r"^("+"|".join(colloq_proclitic)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 2),
                (r"^("+"|".join(colloq_proclitic)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 2),
                (r"^("+"|".join(colloq_prefix)+")" + "(.+?)$",2),
                (r"^("+"|".join(colloq_proclitic)+")" + "(.+?)$",2),
                (r"^("+"|".join(colloq_prefix)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)"+ "("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_suffix)+")$", 3),
                (r"^(.+?)" + "("+"|".join(colloq_suffix)+")$",1),
                (r"^("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 2),
                (r"^("+"|".join(colloq_proclitic)+")"+"("+"|".join(colloq_prefix)+")"+"("+"|".join(colloq_prefix)+")" + "(.+?)$", 4),
                (r"^("+"|".join(colloq_prefix)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 3),
                (r"^("+"|".join(colloq_prefix)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 3),
                (r"^("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 2),
                (r"^("+"|".join(colloq_proclitic)+")"+"("+"|".join(colloq_prefix)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 3),
                (r"^("+"|".join(colloq_prefix)+")" + "(.+?)" + "("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_suffix)+")$", 2),
                (r"^(.+?)" + "("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_enclitics)+")$" ,1),
                (r"^(.+)",1)
                
                ]
patterns_nouns=[
                (r"^("+"|".join(colloq_proclitic)+")" + "(.+?)$",2),
                (r"^(.+?)" + "("+"|".join(colloq_enclitics)+")$",1),
                (r"^(.+?)" + "("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_suffix)+")$",1),
                (r"^(.+?)" + "("+"|".join(colloq_suffix)+")$",1),  #مليانة
                (r"^("+"|".join(colloq_proclitic)+")"+"("+"|".join(colloq_proclitic)+")"+"(.+?)$", 3),
                (r"^("+"|".join(colloq_proclitic)+")"+"("+"|".join(pro_def)+")"+"(.+?)$", 3),
                (r"^("+"|".join(colloq_proclitic)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 2),
                (r"^("+"|".join(pro_def)+")"+"(.+?)"+"("+"|".join(colloq_suffix)+")$", 2),
                (r"^("+"|".join(colloq_proclitic)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 2),
                (r"^("+"|".join(pro_def)+")" + "(.+?)"+"("+"|".join(colloq_suffix)+")" + "("+"|".join(colloq_suffix)+")$",2),
                (r"^("+"|".join(pro_def)+")" + "(.+?)$",2),
                (r"^(.+)",1)
                ]
patterns_particle=[(r"^("+"|".join(proclitic_par)+")" + "(.+?)$",2),
                   (r"^(.+?)" + "("+"|".join(colloq_suffix)+")$",1),  
                   (r"^(.+?)" + "("+"|".join(colloq_enclitics)+")$",1),
                   (r"^("+"|".join(proclitic_par)+")"+"("+"|".join(proclitic_par)+")"+"(.+?)$", 3),
                   #(r"^("+"|".join(proclitics)+")"+"(.+?)"+"("+"|".join(enclitics)+")$", 2),
                   (r"^("+"|".join(proclitic_par)+")"+"(.+?)"+"("+"|".join(colloq_enclitics)+")$", 2),
                   (r"^(.+)",1)
                   ]
print("Verbs:\n")
print(60 * '==')

for word in tokens:
    for pat in patterns_verbs:
        matchs=re.search(pat[0],word)
        if matchs:
            if matchs.group(pat[1])in verbstem:
                print(word, matchs.groups())
print("particles:\n")
print(60 * '==')
for word in tokens:
    for pat in patterns_particle:
        matchs=re.search(pat[0],word)
        if matchs:
            if matchs.group(pat[1])in particle_stem:
                print(word, matchs.groups())
print("nouns:\n")
print(60 * '==')
for word in tokens:
    for pat in patterns_nouns:
        matchs=re.search(pat[0],word)
        if matchs:
            if matchs.group(pat[1])in nounstem:
                print(word, matchs.groups())
# Out:
# no. of verb stems:  211
# no. of noun stems:  294
# no. of prepositions:  21
# no. of particles:  115
# no. of adjectives:  104
# ...
# Mathod 1:
#
# word: عن is a particle
# عن ('عن',)
# N Word is : سلحفاة
#   Proclitics: None
#   Prefix: None
#   Stem: سلحفاة
#   Suffix: None
#   Enclitic: None
# word: في is a particle
# في ('في',)
# N Word is : غابة
#   Proclitics: None
#   Prefix: None
#   Stem: غابة
#   Suffix: None
#   Enclitic: None
# V Word is: يكفي
#   Proclitics: None
#   Prefix: ي
#   Stem: كفي
#   Suffix: None
#   Enclitic: None
# word: كل is a particle
# كل ('كل',)
# V Word is: كان
#   Proclitics: None
#   Prefix: None
#   Stem: كان
#   Suffix: None
#   Enclitic: None
# word: في is a particle
# في ('في',)
# N Word is : الغابة
#   Proclitics: ال
#   Prefix: None
#   Stem: غابة
#   Suffix: None
#   Enclitic: None
# word: دي is a particle
# دي ('دي',)
# word: ان is a particle
# ان ('ان',)
# V Word is: كان
#   Proclitics: None
#   Prefix: None
#   Stem: كان
#   Suffix: None
# ...
